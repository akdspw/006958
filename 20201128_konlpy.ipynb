# %% [markdown]
# <a href="https://colab.research.google.com/github/akdspw/006958/blob/master/20201128_konlpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pwd
# Out:
# Mounted at /content/drive
# /content

# %%
import keras
data_path = '/content/drive/My Drive/Colab Notebooks/data/data.csv'

# %%
import pandas as pd  
df = pd.read_csv(data_path, chunksize=1, header=None, encoding='utf-8')
# df = pd.read_csv('./data.csv', chunksize=1, header=None, encoding='utf-8')

# %%
lines = []
for line in pd.read_csv(data_path, encoding='utf-8', header=None, chunksize=1):
    lines.append(line.iloc[0,0])

# %%
lines
# Out:
# ['1)회복에는 시간이 필요하고,  중독에 있는 때는 정서적 으로 불안정했음',
#  '2)지속적으로 변화하는 것을 느끼게 되었음  ',
#  '3)모임에 참여하는 기간이 길어지면서 조금씩 신뢰가 쌓이고 관계가 회복됨  ',
#  '4)화의 문제가 배우자 때문이 아니라 나의 내면의 문제라는  것을 받아들이는데 많은 시간이 필요했음  ',
#  '5)모임에 참여하면서 이전에 아픔이 많이 치유가 되었음',
#  '6)화, 두려움, 불안의 문제가 남편 때문이 아니라 나의 내면의 문제라는 것을 볼 수 있게됨  ',
#  '7)두려움과 화의 문제가 나의 내면의 문제 라는 것을 인정하게 되었음  ',
#  '8)두려움과 화가 남편때문이 아니라 나의 내면의 문제라 는 것을 알게 되었음  ',
#  '9)모임에 참여하면서 감정을 문제가 나의 내면에서 일어나는 문제라는 것을 알게 되었 고 그래서 내 안의 화를 조절하기 위해서 노력함',
#  '10)정서적으로 안정이 되고, 신앙이 다시 회복되고 있음  ',
#  '11)하나님을 만나게 되었고 슬픔과 나에 대한 실망하는 마음이 사리지게 되었음  ',
#  '12)중독행위를 멈추는 것에서 영혼육이 치유되는 과정을 경험하게 되어짐   ',
#  '13)모임에 나오면서 신앙을 갖게 되고, 화를 내는 것이  죄를 짖는 것이라는 것을 알게 되었고, 분노를 누그러 뜨리게 되었음  ',
#  '14)대부분의 감정조절이 제 자리에 돌아오게 되었음  ',
#  '15)감정에 끌리지 않고 정직하게 상대방을 대하기 시작하면서 올바르지 않는 것에 대해 거절하는 것이 쉬워졌음 ',
#  '16)·힘들었던 정서가 떨어져 나갔고, 더 이상 정서에 노예가 되지 자유한 삶을 살고 있음. ',
#  '17)남편의 중독으로 부정적인 감정에 지배를 받았고, 회복되면서 나의 감정을 알아주게 되었음   ',
#  '18)감정에 휘말려서 지냈으나,  남편과 분리 시키면서 감정을 조절할 수 있게 되었음   ',
#  '19)화를 내면서 자신의 열등감을 숨기려고 했음 ',
#  '20)남편이 중독 중일 때에는 자존감이 바닥이었고 늘 화가 나 있었음  ',
#  '21)남편이 중독일 때에는 너무 외롭고 자존감이 떨어져 깊은  우울을 경험함  ',
#  '22)남편때문에 두려움과 분노가 있는 것 같지만, 시간이 지나면서 자신감이 없고, 이기심 때문에 화를 냈던 것이라는 것을 알게 되었음  ',
#  '23)중독으로부터 회복되면서',
#  '정서적인 문제가 해결되고, 자신의 소중함도 알게 되었음  ',
#  '24)중독에 있을 때에는 정상적인 삶을 살 수 없기 때문에, 불안하고 두려웠고 늘 아내에게  거짓말을 해야 했음 ',
#  '25)화의 문제가 중독과 깊이 관련되어 있다는 것을 알게  되었음 ',
#  '26)중독에 있을 때에는 감정에 이끌리는 삶을 살았고, 약물에 취해서 오는 허무함, 공허함 이 많이 있었음',
#  '27)아내에게 나의 자존심 때문에 정직하게 말하지 못하는 성격적 결함이 결국은 커다란 일을 저질르고 마는 결과를 나타냄 ',
#  '28)내가 성공하려고 집착하다가 보니 성공하지 못한 실망감 때문에 내가 중독에 빠질 수  밖에 없었음',
#  '29) 내가 잘못 살고 있다는 것을 아내가 지적하면 화가 남  ',
#  '30)중독이 멈추면서 가정에 경제적 으로 도움을 주면서 아내와 관계가 좋아짐  ',
#  '31)습성이나 가치관으로 인해서 내 잘못인 줄 알면서도 아내에게 화를 내었고, 아직도  중독때문에 두려움과 불안이 있음  ',
#  '32)남편을 공격하는 것을 멈추니까 남편도 나에 대해서 마음을 조금씩 편하게 갖기  시작했음 ',
#  '33)즉시 시인하지않고 고쳐가지 않으면, 회복할 수 없는 수렁으로 빠지게 됨을 알게됨 ',
#  '34)남편는 중독에서 회복되는 중인데 나는 계 속 중독 중인 남편을 계속 기억하고 힘들 어 하는 나를 알게 되었음   ',
#  '35)중독에 대한 고통의 감정을 함께 나눌 수 있었음',
#  '36)남편의 중독을 막기 위해 모든 일을 했지만 소용이 없었고, 남편에 의존되어 있던 것에서 분리되면서, 남편을 이해하게 됨  ',
#  '37)남편이 중독에 있을 때에 어떤 해결 방법도 없었고, 하나님의 은혜로 남편이 회복되었음  ',
#  '38)남편의 회복은 남편 자신만이 결정할 수 밖에 없고, 하나님의 은혜만이 남편을 회복시킬 수 있다는 것을 믿게 되었음',
#  '39)아내를 변화시킬 수 없다는 것을 받아들 이게 되었음      ',
#  '40)아내의 생각을 바꾸는 것은 하나님만 할 수 있는 것임을 받아들임 ',
#  '41)아내는 변화의 대상이 아니라 하나님이 내게 주신 선물이라는 것을 알게 되었음  ',
#  '42)중독에서 회복되고 책임을 지게 되면서, 자연스럽게 아내와 분리됨  ',
#  '43)중독의 문제는 나의 책임이지 아내의 책임 이 아님  ',
#  '44)중독의 문제가 아내의 문제이기 보다는 저에게 문제 가 있다는 것을 받아들임   ',
#  '45)중독자로 살았던 지나온 시절의 모든 책임은 나에게 있음  ',
#  '46)하나님의 뜻대로 살려고 노력하면 서 이전 보다 행복 한 삶을 살아가고 있음  ',
#  '47)남편의 일은 남편이 책임지게 하고, 나는 나의 일상적인 삶을 살려고 노력함',
#  '48)남편에 의존에서 벗어나서 독립적으로 살아 가는 것을 배우게 되었음',
#  '49)서로가 의존되었던 것에서 조금씩 분리되 어짐 ',
#  '50)내가 결단했듯이, 아내도 스스로 극복해야 한다는 것을 알게 되었고, 각자의 책임을지게 될 때 서로의 원망에서 자유로와졌음    ',
#  '51)아내를 중독자인 나와 분리시키는 작업이 필요하다는 것을 알게 되었음  ',
#  '52)나뿐만아니라 아내도 함께 변화되어야 한다는 것을 알게 되었음  ',
#  '53)나의 회복은 나의 문제지만, 아내의 회복의 문제는 아내의 몫임  ',
#  '54)모음 후에 부부가 분리되어지는 경험을 함 ',
#  '55)남편에게 의존되어 있는 나를 보게 되었고, 남편과 분리되려고 노력했음    ',
#  '56)가정에 어려움이 왔을 때에 남편과 분리 되어야 하는데, 분리되어 지는데 많은 시간이 흘렀음    ',
#  '57)모임을 통해서 정체성이 회복되니 남편과 나를 분리시킬 수 있게 되었음 ',
#  '58)가장 먼저 재정과 아이들을 남편 으로 분리 함    ',
#  '59)모임을 통해서 남편 빚을 갚지 않는 것으로부터 시작했음 ',
#  '60)중독을 중단시키고자하는 여러가 지 노력이 효과가 없다는 것을 알았을 때, 답답했음   ',
#  '61)중독 중인 배우자를 어떻게 할 수 없다는 것을 알면서도, 극단적인 남편으로 인해 아직도 힘듬   ',
#  '62)배우자의 중독으로 감정이 흔들리고, 도저히 해결 방법이 없다는 절망 속에 살았음   ',
#  '63)배우자의 중독에 대해서 제가 할 수 있는 것은 아무 것도 없었음  ',
#  '64)육체적으로 정신적으로 그리고 영적으로 성숙하면서 다시 일어서게 되었음 ',
#  '65)나의 의지로 중독에서 벗어날 수 없다는 것을 인정하고, 하나님께 맡길 때 회복이 시작되었음 ',
#  '66) 신앙으로 견디어준 아내가 감사하 고, 회복된 것은 모두 하나님의 은혜로 받아들임   ',
#  '67)내가 할 수 있는 일과 또한 내가 할 수 없는 것들이 무엇인지 구별하게 되었고,  내가 할 수 없는 것은 하나님 에게 맡기게 되어 평안해짐   ',
#  '68)하나님께 의지해서 살아야만  흔들리 지 않 고 영적 성숙나아갈 수 있다는 것을  알게 됨  ',
#  '69)하나님이 나를 지금까지 지켜주고 있다고 믿음',
#  '70)중독에 대해서도 내가 어떻게 할 수 있는 것이 아니라 하나님에게 맡겨야 한다는 것을 알면서도 중독 중에 있음  ',
#  '71)회복되는 과정을 통해 아내와 함께 신앙이 점점 깊어감  ',
#  '72)하나님의 은혜로 나의 변화가 시작되었고, 부부간에도 판단하고 비난하던 것에서 변화 가 오게 되었음 ',
#  '73)나의 의지로 중독에서 벗어날 수 없다는 것 을 인정하고, 하나님께 맡길 때 회복이 시작되었음  ',
#  '74)회복되면서 하나님의 뜻을 따르려 고 노력하 면서 제대로 된 인간의  길을 걸어갈 수 있게 되었음   ',
#  '75)남편을 중독에서 회복하게 하신 것은 전적 으로 하나님이 하셨다는 것을 시간이 지나서 알게 되었음  ',
#  '76)나의 삶의 행복은 내가 결정하는 것을 영적 각성을 통해 알게되었고, 남편의 회복을 하나 님에게 맡길 수 있었음  ',
#  '77)남편을 이해하고, 신앙안에서 하나가 되려고 함   ',
#  '78)상처입은 치우자(wounded healer) 로 거듭 나는 것이 하나님 안에서 영적으로 회복되는 것임을 알게 됨     ',
#  '79)나는 어떻게 할 수 없음을 받아들 이고, 하나 님에게 맡기기 시작하면서 내 마음이 편해졌음  ',
#  '80)우리 부부가 헤어지지 않고 신앙안에서 자녀에게 가정이라는 울타리를 지켰다는 것이 감사함 ',
#  '81)남편은 다시 재발할 수 있기 때문에 하나님 안에서 함께 노력함',
#  '82)무기력으로 하나님에게 나아가고, 은혜없이 는 전혀 살수 없는 것을 깨달음 ',
#  '83)중독자가 아니였으면 이런 긍정적인 성숙의 길들을 갈 수 없었기 때문에, 과거 중독자임 을 감사로  받아들 이게 되었음. ',
#  '84)하나님의 뜻대로 살려고 노력하면 서 이전 보다 행복한 삶을 살아가고 있음  ',
#  '85)남편이 중독자가 되게 해서 나를 불행한 상황에 처하게 한 것도 하나님 의 의도라는 것을 받아들이게 되었음    ',
#  '86)나의 어려움도 하나님의 섭리가 있었다는 것을 알게 되었음',
#  '87)중독이 진행성 정신질환 병이기 때문에, 의지로만 으로는 치유가 불가능 했고, 치유받 으면 증세가 호전된다는 것을 알게됨    ',
#  '88)모임에 통해  중독에서 치유될 수 있다는 확신을 갖게 되었음   ',
#  '89)남편의 중독이 병이라는 것을 알게 되었고 그것이 나의 잘못이 아니라는 것을 알게됨    ',
#  '90)남편의 중독이 일종의 질병이라는 것을 이해하면서 희망을 갖게  되었음',
#  '91)아내를 하나님의 관점에서 하나의 인격으로 하나님의 작품으로 이해하 고 친밀하게 관계 할 때에 서로 성장할 수 있었음  ',
#  '92)도박 중독에서 회복되는 과정에 하나님을 알게 되었고, 날마다 신앙에 의지해서 살아 가는 삶을 통해서, 지금은 하나님 안에서 소중한 사람이라는 것을 믿게 되었음   ',
#  '93)남편의 중독으로 낮은 자존감으로 살았으나, 모임 후에 신앙이 회복되고 소중한 존재로 나를 받아들이게 되었음  ',
#  '94)모임에 참여하면서 신앙안에서 내가 소중한 존재라는 것을 알게 되었음',
#  '95)삶이 변하기 시작하고, 말씀이 새롭게 적용 되고 있음  ',
#  '96)회복된 것이 아니라 회복되어가는 과정 이라 고 생각함    ',
#  '97)지금과 같은 관계회복은 오랜 시간에 걸쳐서 서서히 회복되어 지금에 이르렀음   ',
#  '98)아내를 있는 그대로 받아들여지게 될 때 성숙한 관계가 되어짐을 경험 했음 ',
#  '99)남편이 중독의 문제가 자녀의 문제로 넘어 가면서 더욱 힘겨움  ',
#  '100)모임 전에는 남편이 중독에 더 빠질까 봐 거절하는 것이 두려웠으나 회복모임 을 참여한 후에는 단호하게 중독에 대해 거절하게 되었음  ',
#  '101)남편의 중독을 나의 방법으로 멈추게 할 수 없다는 것을 알게 되었고, 내가 해야할 일을 마음의 평정을 유지하는 것이라는 것을 알게 되었음   ',
#  '102)남편의 중독을 견디는 힘은 신앙 뿐 이 었음',
#  '103)중독으로 자녀들이 상처를 받은 것에 대해 죄책감이 있음   ',
#  '104)중독으로 자녀들이 어려움을 겪고 있다는 것이 마음 이 아픔  ',
#  '105)남편의 중독이 심했을 때에 정서 적으로 불안전해서 자녀들을 돌보지 못함',
#  '106)지금도 회복되어가는 과정에 있고, 아내와 나를 분리시켜서 문제를 개관적으로 보려함  ',
#  '107)회복과정을 통해서 저를 객관적으로 볼 수 있는 안목을 갖게 되었음 ',
#  '108) 중독 중에는  나의 역점 때문에  아내가 요구하는 것을 대부분 들어 주었음   ',
#  '109) 아내가 나를 비난하기 보다는 이해해주길  바람  ',
#  '110) 모임에 참여하면서 나로 인해서 가정이 어려워졌다는 것을 인정하게 됨  ',
#  '111)부정적인 감정으로 서로 묶여 있었고, 분화 되지 않을 때는 나는 더욱  아내의 영향을 많이 받음 ',
#  '112)·모임을 통해  중독에서 치유될 수 있다는 확신을 갖게 되었음   ',
#  '113)회복되면서 하나님의 뜻을 따르려고 노력하 면서 제대로 된 인간의 길을 걸어갈 수 있게 되었음   ',
#  '114)남편이 중독자가 되는데 조력한 이유는 남편보다는 나 자신을 위해서 였다는 것을 알게됨',
#  '115)남편의 중독 행위와  남편이라는 사람을 분리시키는 것을 배움',
#  '116)남편은 섬에 사는 사람같이 소통 이 어려움',
#  '117) 자신을 객관적으로 보게 되었음 ',
#  '118)회복과정을 통해서 저를 객관적 으로 볼 수 있는 안목을 갖게 되었음 ',
#  '119)고통스러울 때는 생각하지 못했 지만 회복 되고 나서 나를 되돌아 보니까 그 고통이 나에게 축복이 되었 구나 생각하게 되었음  ',
#  '120)남편의 중독이 병이라는 것을 알게 되었고, 도박하는 것과 남편 이라는 사람 자체를 분리 시키게 되면서 남편의 장점이 보였음',
#  '121)중독은 배우자 때문이 아니라 저의 문제 라는 것을 인정함 ',
#  '122) 내가 할 수 있다는 교만이 결국 중독에서 벗어날 수 없게 하는 것이라 는 것을 알게 됨',
#  '123)아직도 내가 하고 싶은 것을 우선으로 하고, 모임을 통해서 나 자신이 잘못되어 있다는 것을 인정하게 되었음  ',
#  '124)내가 중독을 멈추게 되면 서로 대화가 좋아 지고, 다시 중독이 시작되 면 싸우게 됨  ',
#  '125)하나님에게 맡기지 못하고 자신 이 해결 하려고 하는 부분은 아직도 남아있음   ',
#  '126)성공을 위해 굉장히 열심을 내었 지만 내면 의 주체는 거짓된 자아, 강한 에고가 발동 되고 그 중심에 하나님이 없었음',
#  '127) 아내가 나로 인해 정신병을 얻게 되었다는 것을 알고 평생 아내의 회복을 도와야 한다 는 마음을 가지게 되었음  ',
#  '128)도박 중독에서 회복되는 과정에 하나님을 알게 되었고, 날마다 신앙에 의지해서 살아 가는 삶을 통해서, 지금 은 하나님 안에서 소중한 사람이라는 것을 믿게 되었음   ',
#  '129)남편의 중독의 문제와 나를 분리하면서 내가 소중한 존재라는 것을 받아들어지게 되었음   ',
#  '130)회복모임에 참여한 후에 아내에 대한 배려가 시작되었음  ',
#  '131)도박 중독자로 있었을 때에 아내가 많은 고통을 당했다는 것을 회복되는 과정에 대화 를 통해 알게 되었음  ',
#  '132)모임에 참여하면서 가정의 화목을 위해 노력하게 되었음   ',
#  '133) 가정을 지켜준 아내가 무엇보다 도 고마움    ',
#  '134)신앙 안에서 아내를 보니 아내가 더욱 소중 해지고, 내 마음 속에 있는 모든 것을 나눌 수 있게 되었음',
#  '135)부부가 서로 대화가 소통이 되고, 나를 이해해주기 시작했음   ',
#  '136)중독자로 살았을 때는 자기 중심적이고, 늘 거짓말을 했기 때문에 아내와 소통이 단절 되었었고, 후에 대화로 이해하게 되었음   ',
#  '137)아내와의  정반대적인 성격때문 에 부부의 대화가 깊지 않음 ',
#  '138) 모임에 참여하면서 서로 대화가 많아졌음  ',
#  '139)다시 회복하는 방법은 대화하는 방법밖에 없음  ',
#  '140)남편이 중독에서 회복되면서  대화를 통해 서로를 이해하게 되었음    ',
#  '141)도박에 관한 대화는 피하고, 서 로 이해하는 대화를 나누게 되었음  ',
#  '142)회복모임을 통해서 남편에게 대화의 기회를 보는 여유가 생김  ',
#  '143)모임을 통해서 대화가 많아지면서 서로의 의견을 분명하게 전할 수 있게 되었음  ',
#  '144)남편은 중독에서 회복 중이고, 서로가 이해 하려고 노력하게 되었음  ',
#  '145)모임을 통해 남편을 많이 이해 하게 되었음 ',
#  '146) 회복모임을 통해서 남편이 회복 되면서 함께 회복되는 축복을 누리고 있음',
#  '147)남편이 모임에 참여해서  변화니 나도 변화 가 일어남  ',
#  '148)중독 때에는 회피하는 일들이 많았음  ',
#  '149)중독 중일 때에는 아내에게 거짓 말을 해야 하니까 아내와 대화하지 않기 위해서 회피함     ',
#  '150)중독에 있을 때에는  회피했던 적이 많았으나, 회복 되어가는 과정 중에 있는 지금 은 회피해야할 일이 없음  ',
#  '151)나의 부족함을 가리기 위해서 많이 화를 내면서 갈등을 회피하고 직면하지 못했으나 회복모임 후에는 직면하려고 노력함   ',
#  '152)남편이 중독에 있을 때에는 어떤 나의 어떤 방법도 남편의 중독을 해결할 수 없었음  ',
#  '153)회복모임 전에는 모두가 거짓말 이었기 때문 에 중독자 남편과 대화는 거의 불가능했음  ',
#  '154)남편이 중독으로 서로 대화로 소통하기 어려움  ',
#  '155)남편은 자신의 일으킨 문제를',
#  '해결하려고 하지 않고 자꾸 숨으려고 하고, 또한 상황을 모면하려고 하는 것이 우선이었음  ',
#  '156)남편이 중독에 있을 때에는 대부 분 거짓말이었기 때문에 대화가 될 수 없었으나 회복 모임 후에 회복되면 서 대화가 시작되었음  ',
#  '157)모임 이전에는 남편과 의사소통 이 어려웠음',
#  '158)나의 중독문제를 아내가 지적할 때 화가 남',
#  '159)남편과 중독에 관한 이야기를 피하면서 대화가 늘어남   ',
#  '160) 아내와 반대적인 성격 때문에 대화 가 깊지 않음  ',
#  '161)모임을 나가면서 아내가  저를 더욱 힘들게 했기 때문에 대화가 안됨  ',
#  '162) 중독에 있을 때 자신에 대한 성찰이 부족함  ',
#  '163)중독이 된 상태에서는 중독행위 가 중요하지, 생활이나 가정이나 어느 것도 제 눈에 들어 오지 않았음',
#  '164)아내가 회복모임에 나가기 시작하면서 갈등이 생겼 고, 자식 학비 때문에 걱정이 됨  ',
#  '165)중독 남편에게 경제적으로 의존 되어 있어서, 남편 에게 버림받는 것을 두려워함',
#  '166)중독은 나의 방법으로 회복되지 않는다는 것을 받아들이게 되었고, 하나님의 도움으로 회복됨  ',
#  '167)내가 할 수 있다는 교만이 결국 중독에서 벗어날 수 없게 하는 것이라 는 것을 알게 되었음 ',
#  '168)할 수 있는 모든 방법을 간구해도 남편의 중독을 어떻게 할 수가 없었음  ',
#  '169)남편의 인생은 남편의 의지로 결정할 때 남편이 삶이 변하는 것을 알게 되었음 ',
#  '170)중독의 문제는 전적으로 나의 문제임  ',
#  '171)서로를 알게 되면서 대화의 관계 가 깊어 졌음 ',
#  '172) 하나님이 나를 지금까지 지켜주 고 있다고 믿음  ',
#  '173)회복모임이 회복의 시작이었고, 나의 회복을 유지 시키는 것도 회복모임임 ',
#  '174)중독에서 회복의 길을 걷게 되면 서 저의 약 점을 그대로 아내에게 인정하고 회피하지 않음    ',
#  '175)중독에 있을 때에는 아내가 힘들 다는 것을 알지 못했고, 모임 후에 나의 중독으로 인해 힘들었다는 것을 알게 되었음',
#  '176)중독에서 회복되면서 회피하지 않게 되었음   ',
#  '177)나의 단점을 고백하고, 더 이상 회피하지 않고 직면 함 ',
#  '178)부부가 회복을 경험하면서 이제는 서로가 할 수 없는 것에 대해서 요구하지 않게 되었음  ',
#  '179)남편을 이해하려고 노력하고, 회피하지 않고 거절할 것은 거절함  ',
#  '180)반드시 넘고 가야할 갈등이라면 직면해야 한다는 현실을 받아들이고 무서워 하거나 회피하지 않게 되었음  ']

# %%
import re

def clean_text(texts):
    corpus = []
    for i in range(0, len(texts)):
        review = re.sub(r'[@%\\*=()/~#&\+á?\xc3\xa1\-\|\.\:\;\!\-\,\_\~\$\'\"]', '',str(texts[i])) #remove punctuation
        review = re.sub(r'\d+','', str(texts[i]))# remove number
        review = review.lower() #lower case
        review = re.sub(r'\s+', ' ', review) #remove extra space
        review = re.sub(r'<[^>]+>','',review) #remove Html tags
        review = re.sub(r'\s+', ' ', review) #remove spaces
        review = re.sub(r"^\s+", '', review) #remove space from start
        review = re.sub(r'\s+$', '', review) #remove space from the end
        corpus.append(review)
    return corpus

pre_corpus_text = clean_text(lines)

# %%
pre_corpus_text
# Out:
# [')회복에는 시간이 필요하고, 중독에 있는 때는 정서적 으로 불안정했음',
#  ')지속적으로 변화하는 것을 느끼게 되었음',
#  ')모임에 참여하는 기간이 길어지면서 조금씩 신뢰가 쌓이고 관계가 회복됨',
#  ')화의 문제가 배우자 때문이 아니라 나의 내면의 문제라는 것을 받아들이는데 많은 시간이 필요했음',
#  ')모임에 참여하면서 이전에 아픔이 많이 치유가 되었음',
#  ')화, 두려움, 불안의 문제가 남편 때문이 아니라 나의 내면의 문제라는 것을 볼 수 있게됨',
#  ')두려움과 화의 문제가 나의 내면의 문제 라는 것을 인정하게 되었음',
#  ')두려움과 화가 남편때문이 아니라 나의 내면의 문제라 는 것을 알게 되었음',
#  ')모임에 참여하면서 감정을 문제가 나의 내면에서 일어나는 문제라는 것을 알게 되었 고 그래서 내 안의 화를 조절하기 위해서 노력함',
#  ')정서적으로 안정이 되고, 신앙이 다시 회복되고 있음',
#  ')하나님을 만나게 되었고 슬픔과 나에 대한 실망하는 마음이 사리지게 되었음',
#  ')중독행위를 멈추는 것에서 영혼육이 치유되는 과정을 경험하게 되어짐',
#  ')모임에 나오면서 신앙을 갖게 되고, 화를 내는 것이 죄를 짖는 것이라는 것을 알게 되었고, 분노를 누그러 뜨리게 되었음',
#  ')대부분의 감정조절이 제 자리에 돌아오게 되었음',
#  ')감정에 끌리지 않고 정직하게 상대방을 대하기 시작하면서 올바르지 않는 것에 대해 거절하는 것이 쉬워졌음',
#  ')·힘들었던 정서가 떨어져 나갔고, 더 이상 정서에 노예가 되지 자유한 삶을 살고 있음.',
#  ')남편의 중독으로 부정적인 감정에 지배를 받았고, 회복되면서 나의 감정을 알아주게 되었음',
#  ')감정에 휘말려서 지냈으나, 남편과 분리 시키면서 감정을 조절할 수 있게 되었음',
#  ')화를 내면서 자신의 열등감을 숨기려고 했음',
#  ')남편이 중독 중일 때에는 자존감이 바닥이었고 늘 화가 나 있었음',
#  ')남편이 중독일 때에는 너무 외롭고 자존감이 떨어져 깊은 우울을 경험함',
#  ')남편때문에 두려움과 분노가 있는 것 같지만, 시간이 지나면서 자신감이 없고, 이기심 때문에 화를 냈던 것이라는 것을 알게 되었음',
#  ')중독으로부터 회복되면서',
#  '정서적인 문제가 해결되고, 자신의 소중함도 알게 되었음',
#  ')중독에 있을 때에는 정상적인 삶을 살 수 없기 때문에, 불안하고 두려웠고 늘 아내에게 거짓말을 해야 했음',
#  ')화의 문제가 중독과 깊이 관련되어 있다는 것을 알게 되었음',
#  ')중독에 있을 때에는 감정에 이끌리는 삶을 살았고, 약물에 취해서 오는 허무함, 공허함 이 많이 있었음',
#  ')아내에게 나의 자존심 때문에 정직하게 말하지 못하는 성격적 결함이 결국은 커다란 일을 저질르고 마는 결과를 나타냄',
#  ')내가 성공하려고 집착하다가 보니 성공하지 못한 실망감 때문에 내가 중독에 빠질 수 밖에 없었음',
#  ') 내가 잘못 살고 있다는 것을 아내가 지적하면 화가 남',
#  ')중독이 멈추면서 가정에 경제적 으로 도움을 주면서 아내와 관계가 좋아짐',
#  ')습성이나 가치관으로 인해서 내 잘못인 줄 알면서도 아내에게 화를 내었고, 아직도 중독때문에 두려움과 불안이 있음',
#  ')남편을 공격하는 것을 멈추니까 남편도 나에 대해서 마음을 조금씩 편하게 갖기 시작했음',
#  ')즉시 시인하지않고 고쳐가지 않으면, 회복할 수 없는 수렁으로 빠지게 됨을 알게됨',
#  ')남편는 중독에서 회복되는 중인데 나는 계 속 중독 중인 남편을 계속 기억하고 힘들 어 하는 나를 알게 되었음',
#  ')중독에 대한 고통의 감정을 함께 나눌 수 있었음',
#  ')남편의 중독을 막기 위해 모든 일을 했지만 소용이 없었고, 남편에 의존되어 있던 것에서 분리되면서, 남편을 이해하게 됨',
#  ')남편이 중독에 있을 때에 어떤 해결 방법도 없었고, 하나님의 은혜로 남편이 회복되었음',
#  ')남편의 회복은 남편 자신만이 결정할 수 밖에 없고, 하나님의 은혜만이 남편을 회복시킬 수 있다는 것을 믿게 되었음',
#  ')아내를 변화시킬 수 없다는 것을 받아들 이게 되었음',
#  ')아내의 생각을 바꾸는 것은 하나님만 할 수 있는 것임을 받아들임',
#  ')아내는 변화의 대상이 아니라 하나님이 내게 주신 선물이라는 것을 알게 되었음',
#  ')중독에서 회복되고 책임을 지게 되면서, 자연스럽게 아내와 분리됨',
#  ')중독의 문제는 나의 책임이지 아내의 책임 이 아님',
#  ')중독의 문제가 아내의 문제이기 보다는 저에게 문제 가 있다는 것을 받아들임',
#  ')중독자로 살았던 지나온 시절의 모든 책임은 나에게 있음',
#  ')하나님의 뜻대로 살려고 노력하면 서 이전 보다 행복 한 삶을 살아가고 있음',
#  ')남편의 일은 남편이 책임지게 하고, 나는 나의 일상적인 삶을 살려고 노력함',
#  ')남편에 의존에서 벗어나서 독립적으로 살아 가는 것을 배우게 되었음',
#  ')서로가 의존되었던 것에서 조금씩 분리되 어짐',
#  ')내가 결단했듯이, 아내도 스스로 극복해야 한다는 것을 알게 되었고, 각자의 책임을지게 될 때 서로의 원망에서 자유로와졌음',
#  ')아내를 중독자인 나와 분리시키는 작업이 필요하다는 것을 알게 되었음',
#  ')나뿐만아니라 아내도 함께 변화되어야 한다는 것을 알게 되었음',
#  ')나의 회복은 나의 문제지만, 아내의 회복의 문제는 아내의 몫임',
#  ')모음 후에 부부가 분리되어지는 경험을 함',
#  ')남편에게 의존되어 있는 나를 보게 되었고, 남편과 분리되려고 노력했음',
#  ')가정에 어려움이 왔을 때에 남편과 분리 되어야 하는데, 분리되어 지는데 많은 시간이 흘렀음',
#  ')모임을 통해서 정체성이 회복되니 남편과 나를 분리시킬 수 있게 되었음',
#  ')가장 먼저 재정과 아이들을 남편 으로 분리 함',
#  ')모임을 통해서 남편 빚을 갚지 않는 것으로부터 시작했음',
#  ')중독을 중단시키고자하는 여러가 지 노력이 효과가 없다는 것을 알았을 때, 답답했음',
#  ')중독 중인 배우자를 어떻게 할 수 없다는 것을 알면서도, 극단적인 남편으로 인해 아직도 힘듬',
#  ')배우자의 중독으로 감정이 흔들리고, 도저히 해결 방법이 없다는 절망 속에 살았음',
#  ')배우자의 중독에 대해서 제가 할 수 있는 것은 아무 것도 없었음',
#  ')육체적으로 정신적으로 그리고 영적으로 성숙하면서 다시 일어서게 되었음',
#  ')나의 의지로 중독에서 벗어날 수 없다는 것을 인정하고, 하나님께 맡길 때 회복이 시작되었음',
#  ') 신앙으로 견디어준 아내가 감사하 고, 회복된 것은 모두 하나님의 은혜로 받아들임',
#  ')내가 할 수 있는 일과 또한 내가 할 수 없는 것들이 무엇인지 구별하게 되었고, 내가 할 수 없는 것은 하나님 에게 맡기게 되어 평안해짐',
#  ')하나님께 의지해서 살아야만 흔들리 지 않 고 영적 성숙나아갈 수 있다는 것을 알게 됨',
#  ')하나님이 나를 지금까지 지켜주고 있다고 믿음',
#  ')중독에 대해서도 내가 어떻게 할 수 있는 것이 아니라 하나님에게 맡겨야 한다는 것을 알면서도 중독 중에 있음',
#  ')회복되는 과정을 통해 아내와 함께 신앙이 점점 깊어감',
#  ')하나님의 은혜로 나의 변화가 시작되었고, 부부간에도 판단하고 비난하던 것에서 변화 가 오게 되었음',
#  ')나의 의지로 중독에서 벗어날 수 없다는 것 을 인정하고, 하나님께 맡길 때 회복이 시작되었음',
#  ')회복되면서 하나님의 뜻을 따르려 고 노력하 면서 제대로 된 인간의 길을 걸어갈 수 있게 되었음',
#  ')남편을 중독에서 회복하게 하신 것은 전적 으로 하나님이 하셨다는 것을 시간이 지나서 알게 되었음',
#  ')나의 삶의 행복은 내가 결정하는 것을 영적 각성을 통해 알게되었고, 남편의 회복을 하나 님에게 맡길 수 있었음',
#  ')남편을 이해하고, 신앙안에서 하나가 되려고 함',
#  ')상처입은 치우자(wounded healer) 로 거듭 나는 것이 하나님 안에서 영적으로 회복되는 것임을 알게 됨',
#  ')나는 어떻게 할 수 없음을 받아들 이고, 하나 님에게 맡기기 시작하면서 내 마음이 편해졌음',
#  ')우리 부부가 헤어지지 않고 신앙안에서 자녀에게 가정이라는 울타리를 지켰다는 것이 감사함',
#  ')남편은 다시 재발할 수 있기 때문에 하나님 안에서 함께 노력함',
#  ')무기력으로 하나님에게 나아가고, 은혜없이 는 전혀 살수 없는 것을 깨달음',
#  ')중독자가 아니였으면 이런 긍정적인 성숙의 길들을 갈 수 없었기 때문에, 과거 중독자임 을 감사로 받아들 이게 되었음.',
#  ')하나님의 뜻대로 살려고 노력하면 서 이전 보다 행복한 삶을 살아가고 있음',
#  ')남편이 중독자가 되게 해서 나를 불행한 상황에 처하게 한 것도 하나님 의 의도라는 것을 받아들이게 되었음',
#  ')나의 어려움도 하나님의 섭리가 있었다는 것을 알게 되었음',
#  ')중독이 진행성 정신질환 병이기 때문에, 의지로만 으로는 치유가 불가능 했고, 치유받 으면 증세가 호전된다는 것을 알게됨',
#  ')모임에 통해 중독에서 치유될 수 있다는 확신을 갖게 되었음',
#  ')남편의 중독이 병이라는 것을 알게 되었고 그것이 나의 잘못이 아니라는 것을 알게됨',
#  ')남편의 중독이 일종의 질병이라는 것을 이해하면서 희망을 갖게 되었음',
#  ')아내를 하나님의 관점에서 하나의 인격으로 하나님의 작품으로 이해하 고 친밀하게 관계 할 때에 서로 성장할 수 있었음',
#  ')도박 중독에서 회복되는 과정에 하나님을 알게 되었고, 날마다 신앙에 의지해서 살아 가는 삶을 통해서, 지금은 하나님 안에서 소중한 사람이라는 것을 믿게 되었음',
#  ')남편의 중독으로 낮은 자존감으로 살았으나, 모임 후에 신앙이 회복되고 소중한 존재로 나를 받아들이게 되었음',
#  ')모임에 참여하면서 신앙안에서 내가 소중한 존재라는 것을 알게 되었음',
#  ')삶이 변하기 시작하고, 말씀이 새롭게 적용 되고 있음',
#  ')회복된 것이 아니라 회복되어가는 과정 이라 고 생각함',
#  ')지금과 같은 관계회복은 오랜 시간에 걸쳐서 서서히 회복되어 지금에 이르렀음',
#  ')아내를 있는 그대로 받아들여지게 될 때 성숙한 관계가 되어짐을 경험 했음',
#  ')남편이 중독의 문제가 자녀의 문제로 넘어 가면서 더욱 힘겨움',
#  ')모임 전에는 남편이 중독에 더 빠질까 봐 거절하는 것이 두려웠으나 회복모임 을 참여한 후에는 단호하게 중독에 대해 거절하게 되었음',
#  ')남편의 중독을 나의 방법으로 멈추게 할 수 없다는 것을 알게 되었고, 내가 해야할 일을 마음의 평정을 유지하는 것이라는 것을 알게 되었음',
#  ')남편의 중독을 견디는 힘은 신앙 뿐 이 었음',
#  ')중독으로 자녀들이 상처를 받은 것에 대해 죄책감이 있음',
#  ')중독으로 자녀들이 어려움을 겪고 있다는 것이 마음 이 아픔',
#  ')남편의 중독이 심했을 때에 정서 적으로 불안전해서 자녀들을 돌보지 못함',
#  ')지금도 회복되어가는 과정에 있고, 아내와 나를 분리시켜서 문제를 개관적으로 보려함',
#  ')회복과정을 통해서 저를 객관적으로 볼 수 있는 안목을 갖게 되었음',
#  ') 중독 중에는 나의 역점 때문에 아내가 요구하는 것을 대부분 들어 주었음',
#  ') 아내가 나를 비난하기 보다는 이해해주길 바람',
#  ') 모임에 참여하면서 나로 인해서 가정이 어려워졌다는 것을 인정하게 됨',
#  ')부정적인 감정으로 서로 묶여 있었고, 분화 되지 않을 때는 나는 더욱 아내의 영향을 많이 받음',
#  ')·모임을 통해 중독에서 치유될 수 있다는 확신을 갖게 되었음',
#  ')회복되면서 하나님의 뜻을 따르려고 노력하 면서 제대로 된 인간의 길을 걸어갈 수 있게 되었음',
#  ')남편이 중독자가 되는데 조력한 이유는 남편보다는 나 자신을 위해서 였다는 것을 알게됨',
#  ')남편의 중독 행위와 남편이라는 사람을 분리시키는 것을 배움',
#  ')남편은 섬에 사는 사람같이 소통 이 어려움',
#  ') 자신을 객관적으로 보게 되었음',
#  ')회복과정을 통해서 저를 객관적 으로 볼 수 있는 안목을 갖게 되었음',
#  ')고통스러울 때는 생각하지 못했 지만 회복 되고 나서 나를 되돌아 보니까 그 고통이 나에게 축복이 되었 구나 생각하게 되었음',
#  ')남편의 중독이 병이라는 것을 알게 되었고, 도박하는 것과 남편 이라는 사람 자체를 분리 시키게 되면서 남편의 장점이 보였음',
#  ')중독은 배우자 때문이 아니라 저의 문제 라는 것을 인정함',
#  ') 내가 할 수 있다는 교만이 결국 중독에서 벗어날 수 없게 하는 것이라 는 것을 알게 됨',
#  ')아직도 내가 하고 싶은 것을 우선으로 하고, 모임을 통해서 나 자신이 잘못되어 있다는 것을 인정하게 되었음',
#  ')내가 중독을 멈추게 되면 서로 대화가 좋아 지고, 다시 중독이 시작되 면 싸우게 됨',
#  ')하나님에게 맡기지 못하고 자신 이 해결 하려고 하는 부분은 아직도 남아있음',
#  ')성공을 위해 굉장히 열심을 내었 지만 내면 의 주체는 거짓된 자아, 강한 에고가 발동 되고 그 중심에 하나님이 없었음',
#  ') 아내가 나로 인해 정신병을 얻게 되었다는 것을 알고 평생 아내의 회복을 도와야 한다 는 마음을 가지게 되었음',
#  ')도박 중독에서 회복되는 과정에 하나님을 알게 되었고, 날마다 신앙에 의지해서 살아 가는 삶을 통해서, 지금 은 하나님 안에서 소중한 사람이라는 것을 믿게 되었음',
#  ')남편의 중독의 문제와 나를 분리하면서 내가 소중한 존재라는 것을 받아들어지게 되었음',
#  ')회복모임에 참여한 후에 아내에 대한 배려가 시작되었음',
#  ')도박 중독자로 있었을 때에 아내가 많은 고통을 당했다는 것을 회복되는 과정에 대화 를 통해 알게 되었음',
#  ')모임에 참여하면서 가정의 화목을 위해 노력하게 되었음',
#  ') 가정을 지켜준 아내가 무엇보다 도 고마움',
#  ')신앙 안에서 아내를 보니 아내가 더욱 소중 해지고, 내 마음 속에 있는 모든 것을 나눌 수 있게 되었음',
#  ')부부가 서로 대화가 소통이 되고, 나를 이해해주기 시작했음',
#  ')중독자로 살았을 때는 자기 중심적이고, 늘 거짓말을 했기 때문에 아내와 소통이 단절 되었었고, 후에 대화로 이해하게 되었음',
#  ')아내와의 정반대적인 성격때문 에 부부의 대화가 깊지 않음',
#  ') 모임에 참여하면서 서로 대화가 많아졌음',
#  ')다시 회복하는 방법은 대화하는 방법밖에 없음',
#  ')남편이 중독에서 회복되면서 대화를 통해 서로를 이해하게 되었음',
#  ')도박에 관한 대화는 피하고, 서 로 이해하는 대화를 나누게 되었음',
#  ')회복모임을 통해서 남편에게 대화의 기회를 보는 여유가 생김',
#  ')모임을 통해서 대화가 많아지면서 서로의 의견을 분명하게 전할 수 있게 되었음',
#  ')남편은 중독에서 회복 중이고, 서로가 이해 하려고 노력하게 되었음',
#  ')모임을 통해 남편을 많이 이해 하게 되었음',
#  ') 회복모임을 통해서 남편이 회복 되면서 함께 회복되는 축복을 누리고 있음',
#  ')남편이 모임에 참여해서 변화니 나도 변화 가 일어남',
#  ')중독 때에는 회피하는 일들이 많았음',
#  ')중독 중일 때에는 아내에게 거짓 말을 해야 하니까 아내와 대화하지 않기 위해서 회피함',
#  ')중독에 있을 때에는 회피했던 적이 많았으나, 회복 되어가는 과정 중에 있는 지금 은 회피해야할 일이 없음',
#  ')나의 부족함을 가리기 위해서 많이 화를 내면서 갈등을 회피하고 직면하지 못했으나 회복모임 후에는 직면하려고 노력함',
#  ')남편이 중독에 있을 때에는 어떤 나의 어떤 방법도 남편의 중독을 해결할 수 없었음',
#  ')회복모임 전에는 모두가 거짓말 이었기 때문 에 중독자 남편과 대화는 거의 불가능했음',
#  ')남편이 중독으로 서로 대화로 소통하기 어려움',
#  ')남편은 자신의 일으킨 문제를',
#  '해결하려고 하지 않고 자꾸 숨으려고 하고, 또한 상황을 모면하려고 하는 것이 우선이었음',
#  ')남편이 중독에 있을 때에는 대부 분 거짓말이었기 때문에 대화가 될 수 없었으나 회복 모임 후에 회복되면 서 대화가 시작되었음',
#  ')모임 이전에는 남편과 의사소통 이 어려웠음',
#  ')나의 중독문제를 아내가 지적할 때 화가 남',
#  ')남편과 중독에 관한 이야기를 피하면서 대화가 늘어남',
#  ') 아내와 반대적인 성격 때문에 대화 가 깊지 않음',
#  ')모임을 나가면서 아내가 저를 더욱 힘들게 했기 때문에 대화가 안됨',
#  ') 중독에 있을 때 자신에 대한 성찰이 부족함',
#  ')중독이 된 상태에서는 중독행위 가 중요하지, 생활이나 가정이나 어느 것도 제 눈에 들어 오지 않았음',
#  ')아내가 회복모임에 나가기 시작하면서 갈등이 생겼 고, 자식 학비 때문에 걱정이 됨',
#  ')중독 남편에게 경제적으로 의존 되어 있어서, 남편 에게 버림받는 것을 두려워함',
#  ')중독은 나의 방법으로 회복되지 않는다는 것을 받아들이게 되었고, 하나님의 도움으로 회복됨',
#  ')내가 할 수 있다는 교만이 결국 중독에서 벗어날 수 없게 하는 것이라 는 것을 알게 되었음',
#  ')할 수 있는 모든 방법을 간구해도 남편의 중독을 어떻게 할 수가 없었음',
#  ')남편의 인생은 남편의 의지로 결정할 때 남편이 삶이 변하는 것을 알게 되었음',
#  ')중독의 문제는 전적으로 나의 문제임',
#  ')서로를 알게 되면서 대화의 관계 가 깊어 졌음',
#  ') 하나님이 나를 지금까지 지켜주 고 있다고 믿음',
#  ')회복모임이 회복의 시작이었고, 나의 회복을 유지 시키는 것도 회복모임임',
#  ')중독에서 회복의 길을 걷게 되면 서 저의 약 점을 그대로 아내에게 인정하고 회피하지 않음',
#  ')중독에 있을 때에는 아내가 힘들 다는 것을 알지 못했고, 모임 후에 나의 중독으로 인해 힘들었다는 것을 알게 되었음',
#  ')중독에서 회복되면서 회피하지 않게 되었음',
#  ')나의 단점을 고백하고, 더 이상 회피하지 않고 직면 함',
#  ')부부가 회복을 경험하면서 이제는 서로가 할 수 없는 것에 대해서 요구하지 않게 되었음',
#  ')남편을 이해하려고 노력하고, 회피하지 않고 거절할 것은 거절함',
#  ')반드시 넘고 가야할 갈등이라면 직면해야 한다는 현실을 받아들이고 무서워 하거나 회피하지 않게 되었음']

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 28.7MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 9.8MB/s
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/fd/96/1030895dea70855a2e1078e3fe0d6a63dcb7c212309e07dc9ee39d33af54/JPype1-1.1.2-cp36-cp36m-manylinux2010_x86_64.whl (450kB)
#      |████████████████████████████████| 460kB 46.3MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/bb/7c/99d51f80f3b77b107ebae2634108717362c059a41384a1810d13e2429a81/tweepy-3.9.0-py2.py3-none-any.whl
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: beautifulsoup4, colorama, JPype1, tweepy, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# Successfully installed JPype1-1.1.2 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2 tweepy-3.9.0

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
data_word=[]
for i in range(len(pre_corpus_text)):
    try:
        data_word.append(okt.nouns(pre_corpus_text[i]))
    except Exception as e:
        continue

# %%
data_word
# Out:
# [['회복', '시간', '중독', '때', '정서'],
#  ['지속', '변화', '것'],
#  ['모임', '참여', '기간', '신뢰', '관계', '회복'],
#  ['화의', '문제', '배우자', '때문', '나', '내면', '문제', '것', '시간'],
#  ['모임', '참여', '이전', '아픔', '치유'],
#  ['화', '두려움', '불안', '문제', '남편', '때문', '나', '내면', '문제', '것', '볼', '수'],
#  ['두려움', '화의', '문제', '나', '내면', '문제', '것', '인정'],
#  ['두려움', '화가', '남편', '때문', '나', '내면', '문제', '것', '알'],
#  ['모임',
#   '참여',
#   '감정',
#   '문제',
#   '나',
#   '내면',
#   '문제',
#   '것',
#   '알',
#   '고',
#   '내',
#   '안',
#   '화',
#   '조절',
#   '위해',
#   '노력',
#   '함'],
#  ['정서', '안정', '신앙', '다시', '회복'],
#  ['하나님', '슬픔', '나', '대한', '마음', '사리', '지게'],
#  ['중독', '행위', '것', '영혼', '육이', '치유', '과정', '경험', '짐'],
#  ['모임', '신앙', '화', '것', '죄', '것', '것', '알', '분노', '누', '리'],
#  ['대부분', '감정', '조절', '제', '자리'],
#  ['감정', '상대방', '대하', '기', '시작', '것', '대해', '거절', '것'],
#  ['정서', '더', '이상', '정서', '노예', '자유', '삶', '살'],
#  ['남편', '중독', '부정', '감정', '지배', '회복', '나', '감정'],
#  ['감정', '휘', '남편', '분리', '감정', '조절', '수'],
#  ['화', '내면', '자신', '열등감'],
#  ['남편', '중독', '중일', '때', '자존감', '바닥', '늘', '화가', '나'],
#  ['남편', '중', '독일', '때', '외', '자존감', '우울', '경험', '함'],
#  ['남편', '때문', '두려움', '분노', '것', '시간', '자신감', '이기심', '때문', '화', '것', '것', '알'],
#  ['중독', '회복'],
#  ['정서', '문제', '해결', '자신', '알'],
#  ['중독', '때', '정상', '삶', '살', '수', '때문', '늘', '아내', '거짓말'],
#  ['화의', '문제', '중독', '깊이', '관련', '것', '알'],
#  ['중독', '때', '감정', '이', '삶', '약물', '취해', '이'],
#  ['아내', '나', '자존심', '때문', '말', '성격', '결함', '은', '일', '마는', '결과'],
#  ['내', '집착', '못', '실망', '감', '때문', '내', '중독', '수'],
#  ['내', '잘못', '살', '것', '아내', '지적', '화가', '남'],
#  ['중독', '가정', '경제', '도움', '아내', '관계'],
#  ['습성', '가치관', '내', '잘못', '줄', '아내', '화', '중독', '때문', '두려움', '불안'],
#  ['남편', '공격', '것', '남편', '나', '대해', '마음', '시작'],
#  ['즉시', '시인', '수', '수렁', '알'],
#  ['남편', '중독', '회복', '중', '나', '계', '속', '중독', '중인', '남편', '계속', '기억', '알'],
#  ['중독', '대한', '고통', '감정', '수'],
#  ['남편', '중독', '위해', '모든', '일', '소용', '남편', '의존', '것', '분리', '남편', '이해'],
#  ['남편', '중독', '때', '해결', '방법', '하나님', '은혜', '남편', '회복'],
#  ['남편', '회복', '남편', '자신', '결정', '수', '하나님', '은혜', '남편', '회복', '수', '것'],
#  ['아내', '변화', '수', '것', '아들', '이'],
#  ['아내', '생각', '것', '하나님', '수', '것임'],
#  ['아내', '변화', '대상', '하나님', '주신', '선물', '것', '알'],
#  ['중독', '회복', '책임', '지게', '자연', '아내', '분리'],
#  ['중독', '문제', '나', '책임', '아내', '책임', '이'],
#  ['중독', '문제', '아내', '문제', '이기', '저', '문제', '것'],
#  ['중독', '자로', '지나', '온', '시절', '모든', '책임', '나'],
#  ['하나님', '노력', '이전', '행복', '삶'],
#  ['남편', '일', '남편', '나', '나', '일상', '삶', '노력', '함'],
#  ['남편', '의존', '독립', '살', '것'],
#  ['서로', '의존', '것', '분리', '어짐'],
#  ['내',
#   '결단',
#   '아내',
#   '스스로',
#   '극복',
#   '것',
#   '알',
#   '각자',
#   '책임',
#   '지게',
#   '때',
#   '서로',
#   '원망',
#   '자유로'],
#  ['아내', '중독', '분리', '작업', '것', '알'],
#  ['나', '아내', '변화', '것', '알'],
#  ['나', '회복', '나', '문제', '아내', '회복', '문제', '아내', '몫임'],
#  ['모음', '후', '부부', '분리', '경험', '함'],
#  ['남편', '의존', '남편', '분리', '노력'],
#  ['가정', '어려움', '때', '남편', '분리', '분리', '시간'],
#  ['모임', '통해', '정체', '회복', '남편', '분리', '수'],
#  ['가장', '먼저', '재정', '아이', '남편', '분리', '함'],
#  ['모임', '통해', '남편', '빚', '것', '시작'],
#  ['중독', '중단', '여러', '노력', '효과', '것', '때'],
#  ['중독', '중인', '배우자', '수', '것', '극단', '남편'],
#  ['배우자', '중독', '감정', '도저히', '해결', '방법', '절망', '속'],
#  ['배우자', '중독', '대해', '제', '수', '것', '아무', '것'],
#  ['육체', '정신', '영적', '다시'],
#  ['나', '의지', '중독', '수', '것', '인정', '하나님', '때', '회복', '시작'],
#  ['신앙', '준', '아내', '감사', '고', '회복', '것', '모두', '하나님', '은혜'],
#  ['내', '수', '일과', '또한', '내', '수', '것', '무엇', '구별', '내', '수', '것', '하나님', '짐'],
#  ['하나님', '의지', '고', '영적', '성숙', '수', '것', '알'],
#  ['하나님', '지금', '믿음'],
#  ['중독', '대해', '서도', '내', '수', '것', '하나님', '것', '중독', '중'],
#  ['회복', '과정', '통해', '아내', '신앙', '점점', '어감'],
#  ['하나님', '은혜', '나', '변화', '시작', '부부', '판단', '비난', '것', '변화'],
#  ['나', '의지', '중독', '수', '것', '인정', '하나님', '때', '회복', '시작'],
#  ['회복', '하나님', '뜻', '고', '노력', '면서', '제대로', '인간', '길', '수'],
#  ['남편', '중독', '것', '전적', '하나님', '것', '시간', '알'],
#  ['나',
#   '삶',
#   '행복',
#   '내',
#   '결정',
#   '것',
#   '영적',
#   '각성',
#   '통해',
#   '알',
#   '남편',
#   '회복',
#   '하나',
#   '님',
#   '수'],
#  ['남편', '이해', '신앙', '안', '하나', '함'],
#  ['상처', '로', '거듭', '나', '것', '하나님', '안', '영적', '회복', '것임', '알'],
#  ['나', '수', '음', '아들', '하나', '님', '시작', '내', '마음'],
#  ['우리', '부부', '신앙', '안', '자녀', '가정', '울타리', '것'],
#  ['남편', '다시', '재발', '수', '때문', '하나님', '안', '노력', '함'],
#  ['무기', '하나님', '은혜', '전혀', '살수', '것', '깨달음'],
#  ['중독', '긍정', '성숙', '수', '때문', '과거', '중독', '자임', '감사', '아들', '이'],
#  ['하나님', '노력', '이전', '삶'],
#  ['남편', '중독', '상황', '처', '것', '하나님', '의', '의도', '것'],
#  ['나', '어려움', '하나님', '섭리', '것', '알'],
#  ['중독',
#   '진행',
#   '정신질환',
#   '병',
#   '이기',
#   '때문',
#   '의지',
#   '로만',
#   '치유',
#   '불가능',
#   '치유',
#   '증세',
#   '호전',
#   '것',
#   '알'],
#  ['모임', '통해', '중독', '치유', '수', '확신'],
#  ['남편', '중독', '병', '것', '알', '그것', '나', '잘못', '것', '알'],
#  ['남편', '중독', '일종', '질병', '것', '이해', '희망'],
#  ['아내', '하나님', '관점', '하나', '인격', '하나님', '작품', '이해', '고', '관계', '때', '서로', '수'],
#  ['도박',
#   '중독',
#   '회복',
#   '과정',
#   '하나님',
#   '알',
#   '날',
#   '신앙',
#   '의지',
#   '살',
#   '삶',
#   '통해',
#   '지금',
#   '하나님',
#   '안',
#   '사람',
#   '것'],
#  ['남편', '중독', '자존감', '모임', '후', '신앙', '회복', '존재'],
#  ['모임', '참여', '신앙', '안', '내', '존재', '것', '알'],
#  ['삶', '시작', '말씀', '적용'],
#  ['회복', '것', '회복', '과정', '고', '생각', '함'],
#  ['지금', '관계', '회복', '시간', '서서히', '회복', '지금', '이르렀음'],
#  ['아내', '그대로', '때', '관계', '짐', '경험'],
#  ['남편', '중독', '문제', '자녀', '문제', '가면', '더욱', '움'],
#  ['모임',
#   '전',
#   '남편',
#   '중독',
#   '더',
#   '거절',
#   '것',
#   '회복',
#   '모임',
#   '참여',
#   '후',
#   '단호',
#   '중독',
#   '대해',
#   '거절'],
#  ['남편',
#   '중독',
#   '나',
#   '방법',
#   '수',
#   '것',
#   '알',
#   '내',
#   '일',
#   '마음',
#   '평정',
#   '유지',
#   '것',
#   '것',
#   '알'],
#  ['남편', '중독', '힘', '신앙', '뿐', '이'],
#  ['중독', '자녀', '상처', '것', '대해', '죄책감'],
#  ['중독', '자녀', '어려움', '것', '마음', '이', '아픔'],
#  ['남편', '중독', '때', '정서', '적', '불안전', '자녀'],
#  ['지금', '회복', '과정', '아내', '분리', '문제', '개관', '함'],
#  ['회복', '과정', '통해', '저', '객관', '볼', '수', '안목'],
#  ['중독', '중', '나', '역점', '때문', '아내', '요구', '것', '대부분'],
#  ['아내', '비난', '이해', '바람'],
#  ['모임', '참여', '나로', '가정', '것', '인정'],
#  ['부정', '감정', '서로', '분화', '때', '나', '더욱', '아내', '영향'],
#  ['모임', '통해', '중독', '치유', '수', '확신'],
#  ['회복', '하나님', '뜻', '노력', '면서', '제대로', '인간', '길', '수'],
#  ['남편', '중독', '조력', '이유', '남편', '나', '자신', '위해', '것', '알'],
#  ['남편', '중독', '행위', '남편', '사람', '분리', '것', '배움'],
#  ['남편', '섬', '사람', '소통', '이', '어려움'],
#  ['자신', '객관'],
#  ['회복', '과정', '통해', '저', '객관', '볼', '수', '안목'],
#  ['때', '생각', '회복', '보', '그', '고통', '나', '축복', '구나', '생각'],
#  ['남편', '중독', '병', '것', '알', '도박', '것', '남편', '사람', '자체', '분리', '남편', '장점'],
#  ['중독', '배우자', '때문', '저', '문제', '것', '인정', '함'],
#  ['내', '수', '교만', '중독', '수', '것', '것', '알'],
#  ['내', '것', '우선', '모임', '통해', '나', '자신', '것', '인정'],
#  ['내', '중독', '서로', '대화', '지고', '다시', '중독', '시작', '면'],
#  ['하나님', '못', '자신', '이', '해결', '부분'],
#  ['성공', '위해', '열심', '내면', '의', '주체', '거짓', '자아', '에고', '발동', '그', '중심', '하나님'],
#  ['아내', '나로', '정신병', '것', '알', '평생', '아내', '회복', '도', '마음', '가지'],
#  ['도박',
#   '중독',
#   '회복',
#   '과정',
#   '하나님',
#   '알',
#   '날',
#   '신앙',
#   '의지',
#   '살',
#   '삶',
#   '통해',
#   '지금',
#   '은',
#   '하나님',
#   '안',
#   '사람',
#   '것'],
#  ['남편', '중독', '문제', '분리', '내', '존재', '것'],
#  ['회복', '모임', '참여', '후', '아내', '대한', '배려', '시작'],
#  ['도박', '중독', '자로', '때', '아내', '고통', '것', '회복', '과정', '대화', '를', '통해', '알'],
#  ['모임', '참여', '가정', '화목', '위해', '노력'],
#  ['가정', '준', '아내', '무엇', '도', '고마움'],
#  ['신앙', '안', '아내', '아내', '더욱', '중', '해지', '내', '마음', '속', '모든', '것', '수'],
#  ['부부', '서로', '대화', '소통', '이해', '시작'],
#  ['중독',
#   '자로',
#   '때',
#   '자기',
#   '중심',
#   '늘',
#   '거짓말',
#   '때문',
#   '아내',
#   '소통',
#   '단절',
#   '후',
#   '대화',
#   '이해'],
#  ['아내', '정반대', '성격', '때문', '부부', '대화'],
#  ['모임', '참여', '서로', '대화'],
#  ['다시', '방법', '대화', '방법'],
#  ['남편', '중독', '회복', '대화', '통해', '서로', '이해'],
#  ['도박', '관', '대화', '피하', '로', '이해', '대화'],
#  ['회복', '모임', '통해', '남편', '대화', '기회', '여유'],
#  ['모임', '통해', '대화', '서로', '의견', '전', '수'],
#  ['남편', '중독', '회복', '중이', '서로', '이해', '노력'],
#  ['모임', '통해', '남편', '이해'],
#  ['회복', '모임', '통해', '남편', '회복', '회복', '축복', '누리'],
#  ['남편', '모임', '참여', '변화', '변화'],
#  ['중독', '때', '회피', '일'],
#  ['중독', '중일', '때', '아내', '거짓', '말', '아내', '대화', '위해', '회피', '함'],
#  ['중독', '때', '회피', '적', '회복', '과정', '중', '지금', '은', '회피'],
#  ['나',
#   '부족함',
#   '위해',
#   '화',
#   '내면',
#   '갈등',
#   '회피',
#   '직면',
#   '회복',
#   '모임',
#   '후',
#   '직면',
#   '노력',
#   '함'],
#  ['남편', '중독', '때', '나', '방법', '남편', '중독', '해결', '수'],
#  ['회복', '모임', '전', '모두', '거짓말', '때문', '중독', '남편', '대화', '거의'],
#  ['남편', '중독', '서로', '대화', '소통', '어려움'],
#  ['남편', '자신', '문제'],
#  ['해결', '자꾸', '또한', '상황', '모면', '것', '우선'],
#  ['남편',
#   '중독',
#   '때',
#   '대부',
#   '분',
#   '거짓말',
#   '때문',
#   '대화',
#   '수',
#   '회복',
#   '모임',
#   '후',
#   '회복',
#   '대화',
#   '시작'],
#  ['모임', '이전', '남편', '의사소통', '이'],
#  ['나', '중독', '문제', '아내', '지적', '때', '화가', '남'],
#  ['남편', '중독', '관', '이야기', '피하', '면서', '대화'],
#  ['아내', '반대', '성격', '때문', '대화'],
#  ['모임', '아내', '저', '더욱', '때문', '대화'],
#  ['중독', '때', '자신', '대한', '성찰', '부족함'],
#  ['중독', '상태', '중독', '행위', '생활', '가정', '것', '제', '눈', '오지'],
#  ['아내', '회복', '모임', '시작', '갈등', '고', '자식', '학비', '때문', '걱정'],
#  ['중독', '남편', '경제', '의존', '남편', '것', '함'],
#  ['중독', '나', '방법', '회복', '것', '하나님', '도움', '회복'],
#  ['내', '수', '교만', '중독', '수', '것', '것', '알'],
#  ['수', '모든', '방법', '간구', '남편', '중독', '수가'],
#  ['남편', '인생', '남편', '의지', '결정', '때', '남편', '삶', '것', '알'],
#  ['중독', '문제', '전적', '나', '문제', '임'],
#  ['서로', '알', '대화', '관계'],
#  ['하나님', '지금', '고', '믿음'],
#  ['회복', '모임', '회복', '시작', '나', '회복', '유지', '것', '회복', '모임', '임'],
#  ['중독', '회복', '길', '저', '약', '점', '그대로', '아내', '인정', '회피'],
#  ['중독', '때', '아내', '것', '알', '모임', '후', '나', '중독', '것', '알'],
#  ['중독', '회복', '회피'],
#  ['나', '단점', '고백', '더', '이상', '회피', '직면', '함'],
#  ['부부', '회복', '경험', '이제', '서로', '수', '것', '대해', '요구'],
#  ['남편', '이해', '노력', '회피', '거절', '것', '거절', '함'],
#  ['반드시', '가야', '갈등', '라면', '직면', '현실', '거나', '회피']]

# %%
pip install pyLDAvis
# Out:
# Collecting pyLDAvis
#   Downloading https://files.pythonhosted.org/packages/a5/3a/af82e070a8a96e13217c8f362f9a73e82d61ac8fff3a2561946a97f96266/pyLDAvis-2.1.2.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 4.2MB/s
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.35.1)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.18.5)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.1.4)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.17.0)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (2.11.2)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (2.7.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (3.6.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.16.0)
# Collecting funcy
#   Downloading https://files.pythonhosted.org/packages/66/89/479de0afbbfb98d1c4b887936808764627300208bb771fcd823403645a36/funcy-1.15-py2.py3-none-any.whl
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.17.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.17.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.9.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.15.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (20.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (8.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (50.3.2)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (setup.py) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-2.1.2-py2.py3-none-any.whl size=97712 sha256=bf89e0d81a44f0c9bd85013d6b2967b1ed9082664af66879a3ffcf632df9196d
#   Stored in directory: /root/.cache/pip/wheels/98/71/24/513a99e58bb6b8465bae4d2d5e9dba8f0bef8179e3051ac414
# Successfully built pyLDAvis
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-1.15 pyLDAvis-2.1.2

# %%
from konlpy.tag import Mecab 
from tqdm import tqdm 
import re 
from gensim.models.ldamodel import LdaModel 
from gensim.models.callbacks import CoherenceMetric 
from gensim import corpora 
from gensim.models.callbacks import PerplexityMetric 
import logging 
import pickle 
import pyLDAvis.gensim 
from gensim.models.coherencemodel import CoherenceModel 
import matplotlib.pyplot as plt 
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3): 
  coherence_values = [] 
  model_list = [] 
  for num_topics in range(start, limit, step): 
    model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics) 
    model_list.append(model) 
    coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v') 
    coherence_values.append(coherencemodel.get_coherence()) 
  return model_list, coherence_values

# %%
def find_optimal_number_of_topics(dictionary, corpus, processed_data): 
  limit = 20; 
  start = 2; 
  step = 6; 
  model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=processed_data, start=start, limit=limit, step=step)
  x = range(start, limit, step) 
  plt.plot(x, coherence_values) 
  plt.xlabel("Num Topics") 
  plt.ylabel("Coherence score") 
  plt.legend(("coherence_values"), loc='best')
  plt.show()

# %%
if __name__ == '__main__': 
  #processed_data = [sent.strip().split(",") for sent in tqdm(open('./data/tokenized_data.csv', 'r', encoding='utf-8').readlines())]
  # 정수 인코딩과 빈도수 생성 
  dictionary = corpora.Dictionary(data_word) # 출현빈도가 적거나 자주 등장하는 단어는 제거 dictionary.filter_extremes(no_below=10, no_above=0.05) 
  corpus = [dictionary.doc2bow(text) for text in data_word] 
  print('Number of unique tokens: %d' % len(dictionary)) 
  print('Number of documents: %d' % len(corpus)) 
  logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) # 최적의 토픽 수 찾기 
  find_optimal_number_of_topics(dictionary, corpus, data_word)
# Out:
# 2020-11-28 06:16:47,120 : INFO : using symmetric alpha at 0.5
# 2020-11-28 06:16:47,123 : INFO : using symmetric eta at 0.5
# 2020-11-28 06:16:47,129 : INFO : using serial LDA version on this node
# 2020-11-28 06:16:47,131 : INFO : running online (single-pass) LDA training, 2 topics, 1 passes over the supplied corpus of 182 documents, updating model once every 182 documents, evaluating perplexity every 182 documents, iterating 50x with a convergence threshold of 0.001000
# 2020-11-28 06:16:47,132 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# Number of unique tokens: 352
# Number of documents: 182
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# 2020-11-28 06:16:48,830 : INFO : -11.461 per-word bound, 2819.0 perplexity estimate based on a held-out corpus of 182 documents with 1472 words
# 2020-11-28 06:16:48,833 : INFO : PROGRESS: pass 0, at document #182/182
# 2020-11-28 06:16:48,969 : INFO : topic #9 (0.071): 0.075*"아내" + 0.065*"나" + 0.047*"문제" + 0.047*"것" + 0.038*"변화" + 0.029*"회복" + 0.029*"대화" + 0.029*"때문" + 0.019*"함" + 0.019*"알"
# 2020-11-28 06:16:48,970 : INFO : topic #11 (0.071): 0.081*"중독" + 0.071*"것" + 0.053*"남편" + 0.038*"내" + 0.030*"문제" + 0.028*"분리" + 0.023*"아내" + 0.023*"수" + 0.021*"모임" + 0.019*"회복"
# 2020-11-28 06:16:48,979 : INFO : topic #13 (0.071): 0.080*"회복" + 0.069*"중독" + 0.052*"것" + 0.040*"모임" + 0.029*"수" + 0.023*"남편" + 0.023*"시작" + 0.023*"나" + 0.018*"아내" + 0.018*"하나님"
# 2020-11-28 06:16:48,981 : INFO : topic #7 (0.071): 0.093*"남편" + 0.058*"중독" + 0.055*"나" + 0.036*"문제" + 0.031*"수" + 0.031*"것" + 0.020*"아내" + 0.020*"감정" + 0.015*"함" + 0.015*"때문"
# 2020-11-28 06:16:48,988 : INFO : topic #1 (0.071): 0.044*"아내" + 0.044*"때" + 0.023*"것" + 0.023*"중독" + 0.023*"알" + 0.023*"나" + 0.023*"문제" + 0.023*"내" + 0.023*"서로" + 0.023*"책임"
# 2020-11-28 06:16:48,995 : INFO : topic diff=10.727103, rho=1.000000
# 2020-11-28 06:16:49,003 : INFO : using WordOccurrenceAccumulator to estimate probabilities from sliding windows

# %%
from konlpy.tag import Mecab 
from tqdm import tqdm 
import re 
from gensim.models.ldamodel import LdaModel 
from gensim.models.callbacks import CoherenceMetric 
from gensim import corpora 
from gensim.models.callbacks import PerplexityMetric 
import logging 
import pickle
import pyLDAvis.gensim 
from gensim.models.coherencemodel import CoherenceModel 
import matplotlib.pyplot as plt 

if __name__ == '__main__': 
  #processed_data = [sent.strip().split(",") for sent in tqdm(open('./data/tokenized_data.csv', 'r', encoding='utf-8').readlines())] # 정수 인코딩과 빈도수 생성 dictionary = corpora.Dictionary(processed_data) # 출현빈도가 적거나 자주 등장하는 단어는 제거
  dictionary = corpora.Dictionary(data_word) 
  corpus = [dictionary.doc2bow(text) for text in data_word] 
  print('Number of unique tokens: %d' % len(dictionary)) 
  print('Number of documents: %d' % len(corpus)) 
  logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) # 최적의 토픽 수 찾기 => 14개로 나옴 # find_optimal_number_of_topics(dictionary, corpus, processed_data) # exit()
  
  perplexity_logger = PerplexityMetric(corpus=corpus, logger='shell') 
  coherence_logger = CoherenceMetric(corpus=corpus, coherence="u_mass", logger='shell') 
  lda_model = LdaModel(corpus, id2word=dictionary, num_topics=5, passes=30, callbacks=[coherence_logger, perplexity_logger]) 

  topics = lda_model.print_topics(num_words=5) 
  for topic in topics: 
    print(topic) # Compute Coherence Score using c_v 

  coherence_model_lda = CoherenceModel(model=lda_model, texts=data_word, dictionary=dictionary, coherence='c_v') 
  coherence_lda = coherence_model_lda.get_coherence() 
  print('\nCoherence Score (c_v): ', coherence_lda) 

  # Compute Coherence Score using UMass
  coherence_model_lda = CoherenceModel(model=lda_model, texts=data_word, dictionary=dictionary, coherence="u_mass") 
  coherence_lda = coherence_model_lda.get_coherence() 
  print('\nCoherence Score (u_mass): ', coherence_lda) # 저장 

  # pickle.dump(corpus, open('./data/lda/lda_corpus.pkl', 'wb')) 
  #dictionary.save('./data/lda/lda_dictionary.gensim') 
  ##da_model.save('./data/lda/lda_model.gensim') # pyLDAvis html 저장 
  #########lda_visualization = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics=False) 
  #pyLDAvis.save_html(lda_visualization, './data/lda/lda.html') 
  ########pyLDAvis.show(lda_visualization)
# Out:
# 2020-11-28 06:16:53,905 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-11-28 06:16:53,908 : INFO : built Dictionary(352 unique tokens: ['때', '시간', '정서', '중독', '회복']...) from 182 documents (total 1472 corpus positions)
# 2020-11-28 06:16:53,913 : INFO : using symmetric alpha at 0.2
# 2020-11-28 06:16:53,914 : INFO : using symmetric eta at 0.2
# 2020-11-28 06:16:53,916 : INFO : using serial LDA version on this node
# 2020-11-28 06:16:53,918 : INFO : running online (multi-pass) LDA training, 5 topics, 30 passes over the supplied corpus of 182 documents, updating model once every 182 documents, evaluating perplexity every 182 documents, iterating 50x with a convergence threshold of 0.001000
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# Number of unique tokens: 352
# Number of documents: 182
# Streaming output truncated to the last 5000 lines.
# ...
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# 2020-11-28 06:17:05,688 : INFO : Epoch 29: Perplexity estimate: 45.57417064767335
# 2020-11-28 06:17:05,690 : INFO : topic #0 (0.200): 0.088*"남편" + 0.049*"회복" + 0.035*"중독" + 0.035*"수" + 0.034*"것"
# 2020-11-28 06:17:05,692 : INFO : topic #1 (0.200): 0.076*"중독" + 0.065*"문제" + 0.043*"아내" + 0.040*"것" + 0.039*"나"
# 2020-11-28 06:17:05,694 : INFO : topic #2 (0.200): 0.076*"모임" + 0.037*"대화" + 0.030*"남편" + 0.029*"서로" + 0.028*"통해"
# 2020-11-28 06:17:05,697 : INFO : topic #3 (0.200): 0.095*"것" + 0.060*"중독" + 0.046*"알" + 0.040*"남편" + 0.035*"아내"
# 2020-11-28 06:17:05,702 : INFO : topic #4 (0.200): 0.058*"회복" + 0.040*"하나님" + 0.033*"수" + 0.028*"모임" + 0.020*"것"
# 2020-11-28 06:17:05,705 : INFO : using WordOccurrenceAccumulator to estimate probabilities from sliding windows
# (0, '0.088*"남편" + 0.049*"회복" + 0.035*"중독" + 0.035*"수" + 0.034*"것"')
# (1, '0.076*"중독" + 0.065*"문제" + 0.043*"아내" + 0.040*"것" + 0.039*"나"')
# (2, '0.076*"모임" + 0.037*"대화" + 0.030*"남편" + 0.029*"서로" + 0.028*"통해"')
# (3, '0.095*"것" + 0.060*"중독" + 0.046*"알" + 0.040*"남편" + 0.035*"아내"')
# (4, '0.058*"회복" + 0.040*"하나님" + 0.033*"수" + 0.028*"모임" + 0.020*"것"')
#
# Coherence Score (c_v):  0.3410146028175008
#
# Coherence Score (u_mass):  -8.805365234541396

# %%
from gensim import corpora, models
import gensim


ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=7, id2word = dictionary, passes=30)

import pickle
import pyLDAvis.gensim
ldamodel.save('model1.gensim')
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model1.gensim')
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# Streaming output truncated to the last 5000 lines.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# 2020-11-28 06:17:19,652 : INFO : -5.602 per-word bound, 48.6 perplexity estimate based on a held-out corpus of 182 documents with 1472 words
# 2020-11-28 06:17:19,660 : INFO : PROGRESS: pass 16, at document #182/182
# 2020-11-28 06:17:19,719 : INFO : topic #6 (0.143): 0.061*"대화" + 0.060*"서로" + 0.046*"부부" + 0.028*"다시" + 0.027*"아내" + 0.020*"중독" + 0.020*"회복" + 0.019*"신앙" + 0.019*"정서" + 0.019*"것"
# %%
from konlpy.tag import Twitter 
from collections import Counter

# %%
file = open(data_path, 'r')
lists = file.readlines()
file.close()
lists
# Out:
# ['\ufeff"1)회복에는 시간이 필요하고,  중독에 있는 때는 정서적 으로 불안정했음"\n',
#  '2)지속적으로 변화하는 것을 느끼게 되었음  \n',
#  '3)모임에 참여하는 기간이 길어지면서 조금씩 신뢰가 쌓이고 관계가 회복됨  \n',
#  '4)화의 문제가 배우자 때문이 아니라 나의 내면의 문제라는  것을 받아들이는데 많은 시간이 필요했음  \n',
#  '5)모임에 참여하면서 이전에 아픔이 많이 치유가 되었음\n',
#  '"6)화, 두려움, 불안의 문제가 남편 때문이 아니라 나의 내면의 문제라는 것을 볼 수 있게됨  "\n',
#  '7)두려움과 화의 문제가 나의 내면의 문제 라는 것을 인정하게 되었음  \n',
#  '8)두려움과 화가 남편때문이 아니라 나의 내면의 문제라 는 것을 알게 되었음  \n',
#  '9)모임에 참여하면서 감정을 문제가 나의 내면에서 일어나는 문제라는 것을 알게 되었 고 그래서 내 안의 화를 조절하기 위해서 노력함\n',
#  '"10)정서적으로 안정이 되고, 신앙이 다시 회복되고 있음  "\n',
#  '11)하나님을 만나게 되었고 슬픔과 나에 대한 실망하는 마음이 사리지게 되었음  \n',
#  '12)중독행위를 멈추는 것에서 영혼육이 치유되는 과정을 경험하게 되어짐   \n',
#  '"13)모임에 나오면서 신앙을 갖게 되고, 화를 내는 것이  죄를 짖는 것이라는 것을 알게 되었고, 분노를 누그러 뜨리게 되었음  "\n',
#  '14)대부분의 감정조절이 제 자리에 돌아오게 되었음  \n',
#  '15)감정에 끌리지 않고 정직하게 상대방을 대하기 시작하면서 올바르지 않는 것에 대해 거절하는 것이 쉬워졌음 \n',
#  '"16)·힘들었던 정서가 떨어져 나갔고, 더 이상 정서에 노예가 되지 자유한 삶을 살고 있음. "\n',
#  '"17)남편의 중독으로 부정적인 감정에 지배를 받았고, 회복되면서 나의 감정을 알아주게 되었음   "\n',
#  '"18)감정에 휘말려서 지냈으나,  남편과 분리 시키면서 감정을 조절할 수 있게 되었음   "\n',
#  '19)화를 내면서 자신의 열등감을 숨기려고 했음 \n',
#  '20)남편이 중독 중일 때에는 자존감이 바닥이었고 늘 화가 나 있었음  \n',
#  '21)남편이 중독일 때에는 너무 외롭고 자존감이 떨어져 깊은  우울을 경험함  \n',
#  '"22)남편때문에 두려움과 분노가 있는 것 같지만, 시간이 지나면서 자신감이 없고, 이기심 때문에 화를 냈던 것이라는 것을 알게 되었음  "\n',
#  '23)중독으로부터 회복되면서\n',
#  '"정서적인 문제가 해결되고, 자신의 소중함도 알게 되었음  "\n',
#  '"24)중독에 있을 때에는 정상적인 삶을 살 수 없기 때문에, 불안하고 두려웠고 늘 아내에게  거짓말을 해야 했음 "\n',
#  '25)화의 문제가 중독과 깊이 관련되어 있다는 것을 알게  되었음 \n',
#  '"26)중독에 있을 때에는 감정에 이끌리는 삶을 살았고, 약물에 취해서 오는 허무함, 공허함 이 많이 있었음"\n',
#  '27)아내에게 나의 자존심 때문에 정직하게 말하지 못하는 성격적 결함이 결국은 커다란 일을 저질르고 마는 결과를 나타냄 \n',
#  '28)내가 성공하려고 집착하다가 보니 성공하지 못한 실망감 때문에 내가 중독에 빠질 수  밖에 없었음\n',
#  '29) 내가 잘못 살고 있다는 것을 아내가 지적하면 화가 남  \n',
#  '30)중독이 멈추면서 가정에 경제적 으로 도움을 주면서 아내와 관계가 좋아짐  \n',
#  '"31)습성이나 가치관으로 인해서 내 잘못인 줄 알면서도 아내에게 화를 내었고, 아직도  중독때문에 두려움과 불안이 있음  "\n',
#  '32)남편을 공격하는 것을 멈추니까 남편도 나에 대해서 마음을 조금씩 편하게 갖기  시작했음 \n',
#  '"33)즉시 시인하지않고 고쳐가지 않으면, 회복할 수 없는 수렁으로 빠지게 됨을 알게됨 "\n',
#  '34)남편는 중독에서 회복되는 중인데 나는 계 속 중독 중인 남편을 계속 기억하고 힘들 어 하는 나를 알게 되었음   \n',
#  '35)중독에 대한 고통의 감정을 함께 나눌 수 있었음\n',
#  '"36)남편의 중독을 막기 위해 모든 일을 했지만 소용이 없었고, 남편에 의존되어 있던 것에서 분리되면서, 남편을 이해하게 됨  "\n',
#  '"37)남편이 중독에 있을 때에 어떤 해결 방법도 없었고, 하나님의 은혜로 남편이 회복되었음  "\n',
#  '"38)남편의 회복은 남편 자신만이 결정할 수 밖에 없고, 하나님의 은혜만이 남편을 회복시킬 수 있다는 것을 믿게 되었음"\n',
#  '39)아내를 변화시킬 수 없다는 것을 받아들 이게 되었음      \n',
#  '40)아내의 생각을 바꾸는 것은 하나님만 할 수 있는 것임을 받아들임 \n',
#  '41)아내는 변화의 대상이 아니라 하나님이 내게 주신 선물이라는 것을 알게 되었음  \n',
#  '"42)중독에서 회복되고 책임을 지게 되면서, 자연스럽게 아내와 분리됨  "\n',
#  '43)중독의 문제는 나의 책임이지 아내의 책임 이 아님  \n',
#  '44)중독의 문제가 아내의 문제이기 보다는 저에게 문제 가 있다는 것을 받아들임   \n',
#  '45)중독자로 살았던 지나온 시절의 모든 책임은 나에게 있음  \n',
#  '46)하나님의 뜻대로 살려고 노력하면 서 이전 보다 행복 한 삶을 살아가고 있음  \n',
#  '"47)남편의 일은 남편이 책임지게 하고, 나는 나의 일상적인 삶을 살려고 노력함"\n',
#  '48)남편에 의존에서 벗어나서 독립적으로 살아 가는 것을 배우게 되었음\n',
#  '49)서로가 의존되었던 것에서 조금씩 분리되 어짐 \n',
#  '"50)내가 결단했듯이, 아내도 스스로 극복해야 한다는 것을 알게 되었고, 각자의 책임을지게 될 때 서로의 원망에서 자유로와졌음    "\n',
#  '51)아내를 중독자인 나와 분리시키는 작업이 필요하다는 것을 알게 되었음  \n',
#  '52)나뿐만아니라 아내도 함께 변화되어야 한다는 것을 알게 되었음  \n',
#  '"53)나의 회복은 나의 문제지만, 아내의 회복의 문제는 아내의 몫임  "\n',
#  '54)모음 후에 부부가 분리되어지는 경험을 함 \n',
#  '"55)남편에게 의존되어 있는 나를 보게 되었고, 남편과 분리되려고 노력했음    "\n',
#  '"56)가정에 어려움이 왔을 때에 남편과 분리 되어야 하는데, 분리되어 지는데 많은 시간이 흘렀음    "\n',
#  '57)모임을 통해서 정체성이 회복되니 남편과 나를 분리시킬 수 있게 되었음 \n',
#  '58)가장 먼저 재정과 아이들을 남편 으로 분리 함    \n',
#  '59)모임을 통해서 남편 빚을 갚지 않는 것으로부터 시작했음 \n',
#  '"60)중독을 중단시키고자하는 여러가 지 노력이 효과가 없다는 것을 알았을 때, 답답했음   "\n',
#  '"61)중독 중인 배우자를 어떻게 할 수 없다는 것을 알면서도, 극단적인 남편으로 인해 아직도 힘듬   "\n',
#  '"62)배우자의 중독으로 감정이 흔들리고, 도저히 해결 방법이 없다는 절망 속에 살았음   "\n',
#  '63)배우자의 중독에 대해서 제가 할 수 있는 것은 아무 것도 없었음  \n',
#  '64)육체적으로 정신적으로 그리고 영적으로 성숙하면서 다시 일어서게 되었음 \n',
#  '"65)나의 의지로 중독에서 벗어날 수 없다는 것을 인정하고, 하나님께 맡길 때 회복이 시작되었음 "\n',
#  '"66) 신앙으로 견디어준 아내가 감사하 고, 회복된 것은 모두 하나님의 은혜로 받아들임   "\n',
#  '"67)내가 할 수 있는 일과 또한 내가 할 수 없는 것들이 무엇인지 구별하게 되었고,  내가 할 수 없는 것은 하나님 에게 맡기게 되어 평안해짐   "\n',
#  '68)하나님께 의지해서 살아야만  흔들리 지 않 고 영적 성숙나아갈 수 있다는 것을  알게 됨  \n',
#  '69)하나님이 나를 지금까지 지켜주고 있다고 믿음\n',
#  '70)중독에 대해서도 내가 어떻게 할 수 있는 것이 아니라 하나님에게 맡겨야 한다는 것을 알면서도 중독 중에 있음  \n',
#  '71)회복되는 과정을 통해 아내와 함께 신앙이 점점 깊어감  \n',
#  '"72)하나님의 은혜로 나의 변화가 시작되었고, 부부간에도 판단하고 비난하던 것에서 변화 가 오게 되었음 "\n',
#  '"73)나의 의지로 중독에서 벗어날 수 없다는 것 을 인정하고, 하나님께 맡길 때 회복이 시작되었음  "\n',
#  '74)회복되면서 하나님의 뜻을 따르려 고 노력하 면서 제대로 된 인간의  길을 걸어갈 수 있게 되었음   \n',
#  '75)남편을 중독에서 회복하게 하신 것은 전적 으로 하나님이 하셨다는 것을 시간이 지나서 알게 되었음  \n',
#  '"76)나의 삶의 행복은 내가 결정하는 것을 영적 각성을 통해 알게되었고, 남편의 회복을 하나 님에게 맡길 수 있었음  "\n',
#  '"77)남편을 이해하고, 신앙안에서 하나가 되려고 함   "\n',
#  '78)상처입은 치우자(wounded healer) 로 거듭 나는 것이 하나님 안에서 영적으로 회복되는 것임을 알게 됨     \n',
#  '"79)나는 어떻게 할 수 없음을 받아들 이고, 하나 님에게 맡기기 시작하면서 내 마음이 편해졌음  "\n',
#  '80)우리 부부가 헤어지지 않고 신앙안에서 자녀에게 가정이라는 울타리를 지켰다는 것이 감사함 \n',
#  '81)남편은 다시 재발할 수 있기 때문에 하나님 안에서 함께 노력함\n',
#  '"82)무기력으로 하나님에게 나아가고, 은혜없이 는 전혀 살수 없는 것을 깨달음 "\n',
#  '"83)중독자가 아니였으면 이런 긍정적인 성숙의 길들을 갈 수 없었기 때문에, 과거 중독자임 을 감사로  받아들 이게 되었음. "\n',
#  '84)하나님의 뜻대로 살려고 노력하면 서 이전 보다 행복한 삶을 살아가고 있음  \n',
#  '85)남편이 중독자가 되게 해서 나를 불행한 상황에 처하게 한 것도 하나님 의 의도라는 것을 받아들이게 되었음    \n',
#  '86)나의 어려움도 하나님의 섭리가 있었다는 것을 알게 되었음\n',
#  '"87)중독이 진행성 정신질환 병이기 때문에, 의지로만 으로는 치유가 불가능 했고, 치유받 으면 증세가 호전된다는 것을 알게됨    "\n',
#  '88)모임에 통해  중독에서 치유될 수 있다는 확신을 갖게 되었음   \n',
#  '89)남편의 중독이 병이라는 것을 알게 되었고 그것이 나의 잘못이 아니라는 것을 알게됨    \n',
#  '90)남편의 중독이 일종의 질병이라는 것을 이해하면서 희망을 갖게  되었음\n',
#  '91)아내를 하나님의 관점에서 하나의 인격으로 하나님의 작품으로 이해하 고 친밀하게 관계 할 때에 서로 성장할 수 있었음  \n',
#  '"92)도박 중독에서 회복되는 과정에 하나님을 알게 되었고, 날마다 신앙에 의지해서 살아 가는 삶을 통해서, 지금은 하나님 안에서 소중한 사람이라는 것을 믿게 되었음   "\n',
#  '"93)남편의 중독으로 낮은 자존감으로 살았으나, 모임 후에 신앙이 회복되고 소중한 존재로 나를 받아들이게 되었음  "\n',
#  '94)모임에 참여하면서 신앙안에서 내가 소중한 존재라는 것을 알게 되었음\n',
#  '"95)삶이 변하기 시작하고, 말씀이 새롭게 적용 되고 있음  "\n',
#  '96)회복된 것이 아니라 회복되어가는 과정 이라 고 생각함    \n',
#  '97)지금과 같은 관계회복은 오랜 시간에 걸쳐서 서서히 회복되어 지금에 이르렀음   \n',
#  '98)아내를 있는 그대로 받아들여지게 될 때 성숙한 관계가 되어짐을 경험 했음 \n',
#  '99)남편이 중독의 문제가 자녀의 문제로 넘어 가면서 더욱 힘겨움  \n',
#  '100)모임 전에는 남편이 중독에 더 빠질까 봐 거절하는 것이 두려웠으나 회복모임 을 참여한 후에는 단호하게 중독에 대해 거절하게 되었음  \n',
#  '"101)남편의 중독을 나의 방법으로 멈추게 할 수 없다는 것을 알게 되었고, 내가 해야할 일을 마음의 평정을 유지하는 것이라는 것을 알게 되었음   "\n',
#  '102)남편의 중독을 견디는 힘은 신앙 뿐 이 었음\n',
#  '103)중독으로 자녀들이 상처를 받은 것에 대해 죄책감이 있음   \n',
#  '104)중독으로 자녀들이 어려움을 겪고 있다는 것이 마음 이 아픔  \n',
#  '105)남편의 중독이 심했을 때에 정서 적으로 불안전해서 자녀들을 돌보지 못함\n',
#  '"106)지금도 회복되어가는 과정에 있고, 아내와 나를 분리시켜서 문제를 개관적으로 보려함  "\n',
#  '107)회복과정을 통해서 저를 객관적으로 볼 수 있는 안목을 갖게 되었음 \n',
#  '108) 중독 중에는  나의 역점 때문에  아내가 요구하는 것을 대부분 들어 주었음   \n',
#  '109) 아내가 나를 비난하기 보다는 이해해주길  바람  \n',
#  '110) 모임에 참여하면서 나로 인해서 가정이 어려워졌다는 것을 인정하게 됨  \n',
#  '"111)부정적인 감정으로 서로 묶여 있었고, 분화 되지 않을 때는 나는 더욱  아내의 영향을 많이 받음 "\n',
#  '112)·모임을 통해  중독에서 치유될 수 있다는 확신을 갖게 되었음   \n',
#  '113)회복되면서 하나님의 뜻을 따르려고 노력하 면서 제대로 된 인간의 길을 걸어갈 수 있게 되었음   \n',
#  '114)남편이 중독자가 되는데 조력한 이유는 남편보다는 나 자신을 위해서 였다는 것을 알게됨\n',
#  '115)남편의 중독 행위와  남편이라는 사람을 분리시키는 것을 배움\n',
#  '116)남편은 섬에 사는 사람같이 소통 이 어려움\n',
#  '117) 자신을 객관적으로 보게 되었음 \n',
#  '118)회복과정을 통해서 저를 객관적 으로 볼 수 있는 안목을 갖게 되었음 \n',
#  '119)고통스러울 때는 생각하지 못했 지만 회복 되고 나서 나를 되돌아 보니까 그 고통이 나에게 축복이 되었 구나 생각하게 되었음  \n',
#  '"120)남편의 중독이 병이라는 것을 알게 되었고, 도박하는 것과 남편 이라는 사람 자체를 분리 시키게 되면서 남편의 장점이 보였음"\n',
#  '121)중독은 배우자 때문이 아니라 저의 문제 라는 것을 인정함 \n',
#  '122) 내가 할 수 있다는 교만이 결국 중독에서 벗어날 수 없게 하는 것이라 는 것을 알게 됨\n',
#  '"123)아직도 내가 하고 싶은 것을 우선으로 하고, 모임을 통해서 나 자신이 잘못되어 있다는 것을 인정하게 되었음  "\n',
#  '"124)내가 중독을 멈추게 되면 서로 대화가 좋아 지고, 다시 중독이 시작되 면 싸우게 됨  "\n',
#  '125)하나님에게 맡기지 못하고 자신 이 해결 하려고 하는 부분은 아직도 남아있음   \n',
#  '"126)성공을 위해 굉장히 열심을 내었 지만 내면 의 주체는 거짓된 자아, 강한 에고가 발동 되고 그 중심에 하나님이 없었음"\n',
#  '127) 아내가 나로 인해 정신병을 얻게 되었다는 것을 알고 평생 아내의 회복을 도와야 한다 는 마음을 가지게 되었음  \n',
#  '"128)도박 중독에서 회복되는 과정에 하나님을 알게 되었고, 날마다 신앙에 의지해서 살아 가는 삶을 통해서, 지금 은 하나님 안에서 소중한 사람이라는 것을 믿게 되었음   "\n',
#  '129)남편의 중독의 문제와 나를 분리하면서 내가 소중한 존재라는 것을 받아들어지게 되었음   \n',
#  '130)회복모임에 참여한 후에 아내에 대한 배려가 시작되었음  \n',
#  '131)도박 중독자로 있었을 때에 아내가 많은 고통을 당했다는 것을 회복되는 과정에 대화 를 통해 알게 되었음  \n',
#  '132)모임에 참여하면서 가정의 화목을 위해 노력하게 되었음   \n',
#  '133) 가정을 지켜준 아내가 무엇보다 도 고마움    \n',
#  '"134)신앙 안에서 아내를 보니 아내가 더욱 소중 해지고, 내 마음 속에 있는 모든 것을 나눌 수 있게 되었음"\n',
#  '"135)부부가 서로 대화가 소통이 되고, 나를 이해해주기 시작했음   "\n',
#  '"136)중독자로 살았을 때는 자기 중심적이고, 늘 거짓말을 했기 때문에 아내와 소통이 단절 되었었고, 후에 대화로 이해하게 되었음   "\n',
#  '137)아내와의  정반대적인 성격때문 에 부부의 대화가 깊지 않음 \n',
#  '138) 모임에 참여하면서 서로 대화가 많아졌음  \n',
#  '139)다시 회복하는 방법은 대화하는 방법밖에 없음  \n',
#  '140)남편이 중독에서 회복되면서  대화를 통해 서로를 이해하게 되었음    \n',
#  '"141)도박에 관한 대화는 피하고, 서 로 이해하는 대화를 나누게 되었음  "\n',
#  '142)회복모임을 통해서 남편에게 대화의 기회를 보는 여유가 생김  \n',
#  '143)모임을 통해서 대화가 많아지면서 서로의 의견을 분명하게 전할 수 있게 되었음  \n',
#  '"144)남편은 중독에서 회복 중이고, 서로가 이해 하려고 노력하게 되었음  "\n',
#  '145)모임을 통해 남편을 많이 이해 하게 되었음 \n',
#  '146) 회복모임을 통해서 남편이 회복 되면서 함께 회복되는 축복을 누리고 있음\n',
#  '147)남편이 모임에 참여해서  변화니 나도 변화 가 일어남  \n',
#  '148)중독 때에는 회피하는 일들이 많았음  \n',
#  '149)중독 중일 때에는 아내에게 거짓 말을 해야 하니까 아내와 대화하지 않기 위해서 회피함     \n',
#  '"150)중독에 있을 때에는  회피했던 적이 많았으나, 회복 되어가는 과정 중에 있는 지금 은 회피해야할 일이 없음  "\n',
#  '151)나의 부족함을 가리기 위해서 많이 화를 내면서 갈등을 회피하고 직면하지 못했으나 회복모임 후에는 직면하려고 노력함   \n',
#  '152)남편이 중독에 있을 때에는 어떤 나의 어떤 방법도 남편의 중독을 해결할 수 없었음  \n',
#  '153)회복모임 전에는 모두가 거짓말 이었기 때문 에 중독자 남편과 대화는 거의 불가능했음  \n',
#  '154)남편이 중독으로 서로 대화로 소통하기 어려움  \n',
#  '155)남편은 자신의 일으킨 문제를\n',
#  '"해결하려고 하지 않고 자꾸 숨으려고 하고, 또한 상황을 모면하려고 하는 것이 우선이었음  "\n',
#  '156)남편이 중독에 있을 때에는 대부 분 거짓말이었기 때문에 대화가 될 수 없었으나 회복 모임 후에 회복되면 서 대화가 시작되었음  \n',
#  '157)모임 이전에는 남편과 의사소통 이 어려웠음\n',
#  '158)나의 중독문제를 아내가 지적할 때 화가 남\n',
#  '159)남편과 중독에 관한 이야기를 피하면서 대화가 늘어남   \n',
#  '160) 아내와 반대적인 성격 때문에 대화 가 깊지 않음  \n',
#  '161)모임을 나가면서 아내가  저를 더욱 힘들게 했기 때문에 대화가 안됨  \n',
#  '162) 중독에 있을 때 자신에 대한 성찰이 부족함  \n',
#  '"163)중독이 된 상태에서는 중독행위 가 중요하지, 생활이나 가정이나 어느 것도 제 눈에 들어 오지 않았음"\n',
#  '"164)아내가 회복모임에 나가기 시작하면서 갈등이 생겼 고, 자식 학비 때문에 걱정이 됨  "\n',
#  '"165)중독 남편에게 경제적으로 의존 되어 있어서, 남편 에게 버림받는 것을 두려워함"\n',
#  '"166)중독은 나의 방법으로 회복되지 않는다는 것을 받아들이게 되었고, 하나님의 도움으로 회복됨  "\n',
#  '167)내가 할 수 있다는 교만이 결국 중독에서 벗어날 수 없게 하는 것이라 는 것을 알게 되었음 \n',
#  '168)할 수 있는 모든 방법을 간구해도 남편의 중독을 어떻게 할 수가 없었음  \n',
#  '169)남편의 인생은 남편의 의지로 결정할 때 남편이 삶이 변하는 것을 알게 되었음 \n',
#  '170)중독의 문제는 전적으로 나의 문제임  \n',
#  '171)서로를 알게 되면서 대화의 관계 가 깊어 졌음 \n',
#  '172) 하나님이 나를 지금까지 지켜주 고 있다고 믿음  \n',
#  '"173)회복모임이 회복의 시작이었고, 나의 회복을 유지 시키는 것도 회복모임임 "\n',
#  '174)중독에서 회복의 길을 걷게 되면 서 저의 약 점을 그대로 아내에게 인정하고 회피하지 않음    \n',
#  '"175)중독에 있을 때에는 아내가 힘들 다는 것을 알지 못했고, 모임 후에 나의 중독으로 인해 힘들었다는 것을 알게 되었음"\n',
#  '176)중독에서 회복되면서 회피하지 않게 되었음   \n',
#  '"177)나의 단점을 고백하고, 더 이상 회피하지 않고 직면 함 "\n',
#  '178)부부가 회복을 경험하면서 이제는 서로가 할 수 없는 것에 대해서 요구하지 않게 되었음  \n',
#  '"179)남편을 이해하려고 노력하고, 회피하지 않고 거절할 것은 거절함  "\n',
#  '180)반드시 넘고 가야할 갈등이라면 직면해야 한다는 현실을 받아들이고 무서워 하거나 회피하지 않게 되었음  \n']

# %%
twitter = Twitter() 
morphs = [] 

for sentence in lists: 
    morphs.append(twitter.pos(sentence)) 
print(morphs)
# Out:
# /usr/local/lib/python3.6/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [[('\ufeff', 'Foreign'), ('"', 'Punctuation'), ('1', 'Number'), (')', 'Punctuation'), ('회복', 'Noun'), ('에는', 'Josa'), ('시간', 'Noun'), ('이', 'Josa'), ('필요하고', 'Adjective'), (',', 'Punctuation'), ('중독', 'Noun'), ('에', 'Josa'), ('있는', 'Adjective'), ('때', 'Noun'), ('는', 'Josa'), ('정서', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('불안정했음', 'Adjective'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('2', 'Number'), (')', 'Punctuation'), ('지속', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('변화', 'Noun'), ('하는', 'Verb'), ('것', 'Noun'), ('을', 'Josa'), ('느끼게', 'Verb'), ('되었음', 'Verb')], [('3', 'Number'), (')', 'Punctuation'), ('모임', 'Noun'), ('에', 'Josa'), ('참여', 'Noun'), ('하는', 'Verb'), ('기간', 'Noun'), ('이', 'Josa'), ('길어지면서', 'Verb'), ('조금씩', 'Adverb'), ('신뢰', 'Noun'), ('가', 'Josa'), ('쌓이고', 'Verb'), ('관계', 'Noun'), ('가', 'Josa'), ('회복', 'Noun'), ('됨', 'Verb')], [('4', 'Number'), (')', 'Punctuation'), ('화의', 'Noun'), ('문제', 'Noun'), ('가', 'Josa'), ('배우자', 'Noun'), ('때문', 'Noun'), ('이', 'Josa'), ('아니라', 'Adjective'), ('나', 'Noun'), ('의', 'Josa'), ('내면', 'Noun'), ('의', 'Josa'), ('문제', 'Noun'), ('라는', 'Josa'), ('것', 'Noun'), ('을', 'Josa'), ('받아들이는데', 'Verb'), ('많은', 'Adjective'), ('시간', 'Noun'), ('이', 'Josa'), ('필요했음', 'Adjective')], [('5', 'Number'), (')', 'Punctuation'), ('모임', 'Noun'), ('에', 'Josa'), ('참여', 'Noun'), ('하면서', 'Verb'), ('이전', 'Noun'), ('에', 'Josa'), ('아픔', 'Noun'), ('이', 'Josa'), ('많이', 'Adverb'), ('치유', 'Noun'), ('가', 'Josa'), ('되었음', 'Verb'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('6', 'Number'), (')', 'Punctuation'), ('화', 'Noun'), (',', 'Punctuation'), ('두려움', 'Noun'), (',', 'Punctuation'), ('불안', 'Noun'), ('의', 'Josa'), ('문제', 'Noun'), ('가', 'Josa'), ('남편', 'Noun'), ('때문', 'Noun'), ('이', 'Josa'), ('아니라', 'Adjective'), ('나', 'Noun'), ('의', 'Josa'), ('내면', 'Noun'), ('의', 'Josa'), ('문제', 'Noun'), ('라는', 'Josa'), ('것', 'Noun'), ('을', 'Josa'), ('볼', 'Noun'), ('수', 'Noun'), ('있게', 'Adjective'), ('됨', 'Verb'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('7', 'Number'), (')', 'Punctuation'), ('두려움', 'Noun'), ('과', 'Josa'), ('화의', 'Noun'), ('문제', 'Noun'), ('가', 'Josa'), ('나', 'Noun'), ('의', 'Josa'), ('내면', 'Noun'), ('의', 'Josa'), ('문제', 'Noun'), ('라는', 'Josa'), ('것', 'Noun'), ('을', 'Josa'), ('인정', 'Noun'), ('하게', 'Verb'), ('되었음', 'Verb')], [('8', 'Number'), (')', 'Punctuation'), ('두려움', 'Noun'), ('과', 'Josa'), ('화가', 'Noun'), ('남편', 'Noun'), ('때문', 'Noun'), ('이', 'Josa'), ('아니라', 'Adjective'), ('나', 'Noun'), ('의', 'Josa'), ('내면', 'Noun'), ('의', 'Josa'), ('문제', 'Noun'), ('라', 'Josa'), ('는', 'Verb'), ('것', 'Noun'), ('을', 'Josa'), ('알', 'Noun'), ('게', 'Josa'), ('되었음', 'Verb')], [('9', 'Number'), (')', 'Punctuation'), ('모임', 'Noun'), ('에', 'Josa'), ('참여', 'Noun'), ('하면서', 'Verb'), ('감정', 'Noun'), ('을', 'Josa'), ('문제', 'Noun'), ('가', 'Josa'), ('나', 'Noun'), ('의', 'Josa'), ('내면', 'Noun'), ('에서', 'Josa'), ('일어나는', 'Verb'), ('문제', 'Noun'), ('라는', 'Josa'), ('것', 'Noun'), ('을', 'Josa'), ('알', 'Noun'), ('게', 'Josa'), ('되었', 'Verb'), ('고', 'Noun'), ('그래서', 'Adverb'), ('내', 'Noun'), ('안', 'Noun'), ('의', 'Josa'), ('화', 'Noun'), ('를', 'Josa'), ('조절', 'Noun'), ('하기', 'Verb'), ('위해', 'Noun'), ('서', 'Josa'), ('노력', 'Noun'), ('함', 'Noun'), ('\n', 'Foreign')], [('"', 'Punctuation'), ('10', 'Number'), (')', 'Punctuation'), ('정서', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('안정', 'Noun'), ('이', 'Josa'), ('되고', 'Verb'), (',', 'Punctuation'), ('신앙', 'Noun'), ('이', 'Josa'), ('다시', 'Noun'), ('회복', 'Noun'), ('되고', 'Verb'), ('있음', 'Adjective'), ('"', 'Punctuation'), ('\n', 'Foreign')], [('11', 'Number'), (')', 'Punctuation'), ('하나님', 'Noun'), ('을', 'Josa'), ('만나게', 'Verb'), ('되었고', 'Verb'), ('슬픔', 'Noun'), ('과', 'Josa'), ('나', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('실망하는', 'Adjective'), ('마음', 'Noun'), ('이', 'Josa'), ('사리', 'Noun'), ('지게', 'Noun'), ('되었음', 'Verb')], [('12', 'Number'), (')', 'Punctuation'), ('중독', 'Noun'), ('행위', 'Noun'), ('를', 'Josa'), ('멈추는', 'Verb'), ('것', 'Noun'), ('에서', 'Josa'), ('영혼', 'Noun'), ('육이', 'Noun'), ('치유', 'Noun'), ('되는', ...

# %%
noun_adj_adv_list=[] 
for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun'] and ("것" not in word) and ("내" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word): 
            noun_adj_adv_list.append(word) 

print(noun_adj_adv_list)
# Out:
# ['회복', '시간', '중독', '때', '정서', '지속', '변화', '모임', '참여', '기간', '신뢰', '관계', '회복', '화의', '문제', '배우자', '때문', '문제', '시간', '모임', '참여', '이전', '아픔', '치유', '화', '두려움', '불안', '문제', '남편', '때문', '문제', '볼', '두려움', '화의', '문제', '문제', '인정', '두려움', '화가', '남편', '때문', '문제', '알', '모임', '참여', '감정', '문제', '문제', '알', '고', '안', '화', '조절', '위해', '노력', '함', '정서', '안정', '신앙', '다시', '회복', '슬픔', '대한', '마음', '사리', '중독', '행위', '영혼', '육이', '치유', '과정', '경험', '짐', '모임', '신앙', '화', '죄', '알', '분노', '누', '리', '대부분', '감정', '조절', '제', '자리', '감정', '상대방', '대하', '기', '시작', '대해', '거절', '정서', '더', '이상', '정서', '노예', '자유', '삶', '살', '남편', '중독', '부정', '감정', '지배', '회복', '감정', '감정', '휘', '남편', '분리', '감정', '조절', '화', '자신', '열등감', '남편', '중독', '중일', '때', '자존감', '바닥', '늘', '화가', '남편', '중', '독일', '때', '외', '자존감', '우울', '경험', '함', '남편', '때문', '두려움', '분노', '시간', '자신감', '이기심', '때문', '화', '알', '중독', '회복', '정서', '문제', '해결', '자신', '알', '중독', '때', '정상', '삶', '살', '때문', '늘', '화의', '문제', '중독', '깊이', '관련', '알', '중독', '때', '감정', '이', '삶', '약물', '취해', '이', '자존심', '때문', '성격', '결함', '은', '일', '마는', '결과', '집착', '못', '실망', '감', '때문', '중독', '잘못', '살', '지적', '화가', '남', '중독', '가정', '경제', '도움', '관계', '습성', '가치관', '잘못', '줄', '화', '중독', '때문', '두려움', '불안', '남편', '공격', '남편', '대해', '마음', '시작', '즉시', '시인', '알', '남편', '중독', '회복', '중', '계', '속', '중독', '중인', '남편', '계속', '기억', '알', '중독', '대한', '고통', '감정', '남편', '중독', '위해', '모든', '일', '소용', '남편', '의존', '분리', '남편', '이해', '남편', '중독', '때', '해결', '방법', '은혜', '남편', '회복', '남편', '회복', '남편', '자신', '결정', '은혜', '남편', '회복',
# %%
count = Counter(noun_adj_adv_list)

# %%
words = dict(count.most_common())

# %%
words
# Out:
# {'가면': 1,
#  '가야': 1,
#  '가장': 1,
#  '가정': 7,
#  '가지': 1,
#  '가치관': 1,
#  '각성': 1,
#  '각자': 1,
#  '간구': 1,
#  '갈등': 3,
#  '감': 1,
#  '감사': 2,
#  '감정': 11,
#  '개관': 1,
#  '객관': 3,
#  '거듭': 1,
#  '거의': 1,
#  '거절': 5,
#  '거짓': 2,
#  '걱정': 1,
#  '결과': 1,
#  '결단': 1,
#  '결정': 3,
#  '결함': 1,
#  '경제': 2,
#  '경험': 5,
#  '계': 1,
#  '계속': 1,
#  '고': 8,
#  '고마움': 1,
#  '고백': 1,
#  '고통': 3,
#  '공격': 1,
#  '과거': 1,
#  '과정': 10,
#  '관': 2,
#  '관계': 6,
#  '관련': 1,
#  '관점': 1,
#  '교만': 2,
#  '구별': 1,
#  '그': 2,
#  '그대로': 2,
#  '극단': 1,
#  '극복': 1,
#  '긍정': 1,
#  '기': 1,
#  '기간': 1,
#  '기억': 1,
#  '기회': 1,
#  '길': 3,
#  '깊이': 1,
#  '깨달음': 1,
#  '날': 2,
#  '남': 2,
#  '남편': 72,
#  '노력': 13,
#  '노예': 1,
#  '누': 1,
#  '누리': 1,
#  '눈': 1,
#  '늘': 3,
#  '님': 2,
#  '다시': 5,
#  '단절': 1,
#  '단점': 1,
#  '단호': 1,
#  '대부': 1,
#  '대부분': 2,
#  '대상': 1,
#  '대하': 1,
#  '대한': 4,
#  '대해': 7,
#  '대화': 21,
#  '더': 3,
#  '더욱': 4,
#  '도': 2,
#  '도박': 5,
#  '도움': 2,
#  '도저히': 1,
#  '독립': 1,
#  '독일': 1,
#  '두려움': 5,
#  '때': 27,
#  '때문': 21,
#  '또한': 2,
#  '뜻': 2,
#  '라면': 1,
#  '로': 2,
#  '로만': 1,
#  '를': 1,
#  '리': 1,
#  '마는': 1,
#  '마음': 7,
#  '먼저': 1,
#  '면': 1,
#  '면서': 3,
#  '모두': 2,
#  '모든': 4,
#  '모면': 1,
#  '모음': 1,
#  '모임': 31,
#  '몫임': 1,
#  '못': 2,
#  '무기': 1,
#  '무엇': 2,
#  '문제': 26,
#  '믿음': 2,
#  '바닥': 1,
#  '바람': 1,
#  '반대': 1,
#  '반드시': 1,
#  '발동': 1,
#  '방법': 8,
#  '배려': 1,
#  '배우자': 5,
#  '배움': 1,
#  '변화': 8,
#  '병': 3,
#  '보': 1,
#  '볼': 3,
#  '부부': 6,
#  '부분': 1,
#  '부정': 2,
#  '부족함': 2,
#  '분': 1,
#  '분노': 2,
#  '분리': 15,
#  '분화': 1,
#  '불가능': 1,
#  '불안': 2,
#  '불안전': 1,
#  '비난': 2,
#  '빚': 1,
#  '뿐': 1,
#  '사람': 5,
#  '사리': 1,
#  '살': 6,
#  '삶': 11,
#  '상대방': 1,
#  '상처': 2,
#  '상태': 1,
#  '상황': 2,
#  '생각': 4,
#  '생활': 1,
#  '서도': 1,
#  '서로': 13,
#  '서서히': 1,
#  '선물': 1,
#  '섬': 1,
#  '섭리': 1,
#  '성격': 3,
#  '성공': 1,
#  '성숙': 2,
#  '성찰': 1,
#  '소용': 1,
#  '소통': 4,
#  '속': 3,
#  '스스로': 1,
#  '슬픔': 1,
#  '습성': 1,
#  '시간': 6,
#  '시인': 1,
#  '시작': 14,
#  '시절': 1,
#  '신뢰': 1,
#  '신앙': 12,
#  '실망': 1,
#  '아들': 3,
#  '아무': 1,
#  '아이': 1,
#  '아픔': 2,
#  '안': 9,
#  '안목': 2,
#  '안정': 1,
#  '알': 35,
#  '약': 1,
#  '약물': 1,
#  '어감': 1,
#  '어려움': 5,
#  '어짐': 1,
#  '에고': 1,
#  '여러': 1,
#  '여유': 1,
#  '역점': 1,
#  '열등감': 1,
#  '열심': 1,
#  '영적': 4,
#  '영향': 1,
#  '영혼': 1,
#  '오지': 1,
#  '온': 1,
#  '외': 1,
#  '요구': 2,
#  '우리': 1,
#  '우선': 2,
#  '우울': 1,
#  '울타리': 1,
#  '움': 1,
#  '원망': 1,
#  '위해': 7,
#  '유지': 2,
#  '육이': 1,
#  '육체': 1,
#  '은': 3,
#  '은혜': 5,
#  '음': 1,
#  '의': 2,
#  '의견': 1,
#  '의도': 1,
#  '의사소통': 1,
#  '의존': 5,
#  '의지': 7,
#  '이': 10,
#  '이기': 2,
#  '이기심': 1,
#  '이르렀음': 1,
#  '이상': 2,
#  '이야기': 1,
#  '이유': 1,
#  '이전': 4,
#  '이제': 1,
#  '이해': 12,
#  '인간': 2,
#  '인격': 1,
#  '인생': 1,
#  '인정': 7,
#  '일': 5,
#  '일과': 1,
#  '일상': 1,
#  '일종': 1,
#  '임': 2,
#  '자기': 1,
#  '자꾸': 1,
#  '자녀': 5,
#  '자로': 3,
#  '자리': 1,
#  '자식': 1,
#  '자신': 9,
#  '자신감': 1,
#  '자아': 1,
#  '자연': 1,
#  '자유': 1,
#  '자유로': 1,
#  '자임': 1,
#  '자존감': 3,
#  '자존심': 1,
#  '자체': 1,
#  '작업': 1,
#  '작품': 1,
#  '잘못': 3,
#  '장점': 1,
#  '재발': 1,
#  '재정': 1,
#  '저': 6,
#  '적': 2,
#  '적용': 1,
#  '전': 3,
#  '전적': 2,
#  '전혀': 1,
#  '절망': 1,
#  '점': 1,
#  '점점': 1,
#  '정반대': 1,
#  '정상': 1,
#  '정서': 6,
#  '정신': 1,
#  '정신병': 1,
#  '정신질환': 1,
#  '정체': 1,
#  '제': 3,
#  '제대로': 2,
#  '조력': 1,
#  '조절': 3,
#  '존재': 3,
#  '죄': 1,
#  '죄책감': 1,
#  '주신': 1,
#  '주체': 1,
#  '준': 2,
#  '줄': 1,
#  '중': 6,
#  '중단': 1,
#  '중독': 84,
#  '중심': 2,
#  '중이': 1,
#  '중인': 2,
#  '중일': 2,
#  '즉시': 1,
#  '증세': 1,
#  '지고': 1,
#  '지금': 8,
#  '지배': 1,
#  '지속': 1,
#  '지적': 2,
#  '직면': 4,
#  '진행': 1,
#  '질병': 1,
#  '짐': 3,
#  '집착': 1,
#  '참여': 10,
#  '책임': 5,
#  '처': 1,
#  '축복': 2,
#  '취해': 1,
#  '치유': 6,
#  '통해': 17,
#  '판단': 1,
#  '평생': 1,
#  '평정': 1,
#  '피하': 2,
#  '학비': 1,
#  '함': 15,
#  '해결': 6,
#  '해지': 1,
#  '행복': 2,
#  '행위': 3,
#  '현실': 1,
#  '호전': 1,
#  '화': 7,
#  '화가': 4,
#  '화목': 1,
#  '화의': 3,
#  '확신': 2,
#  '회복': 57,
#  '회피': 10,
#  '효과': 1,
#  '후': 8,
#  '휘': 1,
#  '희망': 1,
#  '힘': 1}

# %%
# !pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from WordCloud) (7.0.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from WordCloud) (1.18.5)

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords

# %%
# %matplotlib inline 

import matplotlib 
from matplotlib import rc
rc('font', family='NanumBarunGothic')

# %%
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path = '/content/drive/My Drive/Colab Notebooks/data/NanumBarunGothic.ttf',    
    background_color='white',                             # 배경 색깔 정하기
    colormap = 'Accent_r',                                # 폰트 색깔 정하기
    width = 800,
    height = 800
)

wordcloud_words = wordcloud.generate_from_frequencies(words)

# %%
array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path = '/content/drive/My Drive/Colab Notebooks/data/NanumBarunGothic.ttf',    
    background_color='black',                             # 배경 색깔 정하기
    colormap = 'viridis',                                # 폰트 색깔 정하기
   # colormap = 'Accent_r',                                # 폰트 색깔 정하기
    width = 800,
    height = 800
)

wordcloud_words = wordcloud.generate_from_frequencies(words)

array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path = '/content/drive/My Drive/Colab Notebooks/data/NanumBarunGothic.ttf',    
    background_color='black',                             # 배경 색깔 정하기
  # colormap = 'viridis',                                # 폰트 색깔 정하기
    colormap = 'Accent_r',                                # 폰트 색깔 정하기
    width = 800,
    height = 800
)

wordcloud_words = wordcloud.generate_from_frequencies(words)

array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (800, 800, 3)
